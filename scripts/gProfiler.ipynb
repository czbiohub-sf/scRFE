# %%
from gprofiler import gprofiler
import pandas as pd
import numpy as np

# %%
# https://github.com/vals/python-gprofiler

# %%
# more docs: https://www.rdocumentation.org/packages/gProfileR/versions/0.7.0/topics/gprofiler

# %%
cd /Users/madelinepark/Downloads
# Out:
# /Users/madelinepark/Downloads

# %%
facs3= pd.read_csv('facsAllGenes3m.csv')
facs18= pd.read_csv('facsAllGenes18m.csv')
facs24= pd.read_csv('facsAllGenes24m.csv')
facs3m = list(facs3['3m'])
facs18m = list(facs18['18m'])
facs24m = list(facs24['24m'])

# %%
# enrichment = gprofiler(['Klf4', 'Pax5', 'Sox2', 'Nanog'], organism='mmusculus')
enrichment3 = gprofiler(facs3m, organism='mmusculus')

# %%
enrichment3.sort_values('p.value') #.head()
# Out:
#                     query.number  significant       p.value  term.size  \
# term.id
# GO:0005737                     1         True  7.260000e-85      10422
# GO:0044444                     1         True  7.930000e-84       8155
# GO:0044424                     1         True  5.550000e-75      13275
# GO:0043226                     1         True  5.130000e-74      11903
# GO:0043229                     1         True  8.480000e-74      11660
# ...                          ...          ...           ...        ...
# GO:0051235                     1         True  4.700000e-02        318
# GO:1903555                     1         True  4.810000e-02        135
# REAC:R-MMU-5205685             1         True  4.930000e-02         22
# GO:0002483                     1         True  4.960000e-02         10
# GO:0008250                     1         True  4.960000e-02         10
#
#                     query.size  overlap.size  recall  precision  \
# term.id
# GO:0005737                 845           677   0.801      0.065
# GO:0044444                 845           592   0.701      0.073
# GO:0044424                 845           751   0.889      0.057
# GO:0043226                 845           709   0.839      0.060
# GO:0043229                 845           701   0.830      0.060
# ...                        ...           ...     ...        ...
# GO:0051235                 845            29   0.034      0.091
# GO:1903555                 845            17   0.020      0.126
# REAC:R-MMU-5205685         535             7   0.013      0.318
# GO:0002483                 845             5   0.006      0.500
# GO:0008250                 845             5   0.006      0.500
#
#                                term.id domain  subgraph.number  \
# term.id
# GO:0005737                  GO:0005737     CC              113
# GO:0044444                  GO:0044444     CC              113
# GO:0044424                  GO:0044424     CC              113
# GO:0043226                  GO:0043226     CC              113
# GO:0043229                  GO:0043229     CC              113
# ...                                ...    ...              ...
# GO:0051235                  GO:0051235     BP               21
# GO:1903555                  GO:1903555     BP              116
# REAC:R-MMU-5205685  REAC:R-MMU-5205685    rea               92
# GO:0002483                  GO:0002483     BP               21
# GO:0008250                  GO:0008250     CC              113
#
#                                                             term.name  \
# term.id
# GO:0005737                                                  cytoplasm
# GO:0044444                                           cytoplasmic part
# GO:0044424                                         intracellular part
# GO:0043226                                                  organelle
# GO:0043229                                    intracellular organelle
# ...                                                               ...
# GO:0051235                                    maintenance of location
# GO:1903555              regulation of tumor necrosis factor superf...
# REAC:R-MMU-5205685                     Pink/Parkin Mediated Mitophagy
# GO:0002483             antigen processing and presentation of endo...
# GO:0008250                          oligosaccharyltransferase complex
#
#                     relative.depth  \
# term.id
# GO:0005737                       5
# GO:0044444                       6
# GO:0044424                       4
# GO:0043226                       2
# GO:0043229                       5
# ...                            ...
# GO:0051235                       2
# GO:1903555                       2
# REAC:R-MMU-5205685               1
# GO:0002483                       1
# GO:0008250                       2
#
#                                                          intersection
# term.id
# GO:0005737          COX5A,CCND2,INS2,DAZAP2,GCG,ATP5F1,HK2,RPL13,S...
# GO:0044444          COX5A,CCND2,INS2,GCG,ATP5F1,HK2,RPL13,SERPINF1...
# GO:0044424          COX5A,CCND2,INS2,DAZAP2,GCG,ATP5F1,HK2,RPL13,S...
# GO:0043226          COX5A,CCND2,INS2,DAZAP2,GCG,ATP5F1,HK2,CD52,RP...
# GO:0043229          COX5A,CCND2,INS2,DAZAP2,GCG,ATP5F1,HK2,RPL13,S...
# ...                                                               ...
# GO:0051235          HK2,CALM1,KDELR1,CD36,APOE,MPRIP,CYBA,CAV1,PFN...
# GO:1903555          CD36,HSPB1,CYBA,CD34,CLU,NCL,ERRFI1,SASH3,MIF,...
# REAC:R-MMU-5205685       SQSTM1,UBB,RPS27A,MAP1LC3A,TOMM7,TOMM6,UBA52
# GO:0002483                               TAPBP,B2M,H2-K1,H2-T23,H2-D1
# GO:0008250                                  DAD1,RPN2,RPN1,STT3A,OST4
#
# [1536 rows x 14 columns]

# %%
enrichment18 = gprofiler(facs18m, organism='mmusculus')

# %%
enrichment18.sort_values('p.value')
# Out:
#              query.number  significant        p.value  term.size  query.size  \
# term.id
# GO:0044444              1         True  2.050000e-104       8155         834
# GO:0005737              1         True   3.750000e-99      10422         834
# GO:0044424              1         True   4.740000e-79      13275         834
# GO:0043229              1         True   3.390000e-78      11660         834
# GO:0043226              1         True   7.040000e-78      11903         834
# ...                   ...          ...            ...        ...         ...
# HP:0011970              1         True   4.900000e-02          5         208
# TF:M00801_1             1         True   4.900000e-02        614         836
# GO:0002483              1         True   4.930000e-02         10         834
# GO:0034663              1         True   4.930000e-02         10         834
# GO:0008250              1         True   4.930000e-02         10         834
#
#              overlap.size  recall  precision      term.id domain  \
# term.id
# GO:0044444            617   0.740      0.076   GO:0044444     CC
# GO:0005737            690   0.827      0.066   GO:0005737     CC
# GO:0044424            748   0.897      0.056   GO:0044424     CC
# GO:0043229            700   0.839      0.060   GO:0043229     CC
# GO:0043226            707   0.848      0.059   GO:0043226     CC
# ...                   ...     ...        ...          ...    ...
# HP:0011970              4   0.019      0.800   HP:0011970     hp
# TF:M00801_1            45   0.054      0.073  TF:M00801_1     tf
# GO:0002483              5   0.006      0.500   GO:0002483     BP
# GO:0034663              5   0.006      0.500   GO:0034663     CC
# GO:0008250              5   0.006      0.500   GO:0008250     CC
#
#              subgraph.number  \
# term.id
# GO:0044444                16
# GO:0005737                16
# GO:0044424                16
# GO:0043229                16
# GO:0043226                16
# ...                      ...
# HP:0011970               118
# TF:M00801_1              326
# GO:0002483               165
# GO:0034663                16
# GO:0008250                16
#
#                                                      term.name  \
# term.id
# GO:0044444                                    cytoplasmic part
# GO:0005737                                           cytoplasm
# GO:0044424                                  intracellular part
# GO:0043229                             intracellular organelle
# GO:0043226                                           organelle
# ...                                                        ...
# HP:0011970                         Cerebral amyloid angiopathy
# TF:M00801_1        Factor: CREB; motif: CGTCAN; match class: 1
# GO:0002483      antigen processing and presentation of endo...
# GO:0034663             endoplasmic reticulum chaperone complex
# GO:0008250                   oligosaccharyltransferase complex
#
#              relative.depth                                       intersection
# term.id
# GO:0044444                6  KLF6,COX5A,CCND2,INS2,GCG,ATP5F1,GM2A,RPL13,SE...
# GO:0005737                5  KLF6,COX5A,CCND2,INS2,DAZAP2,GCG,ATP5F1,GM2A,R...
# GO:0044424                4  KLF6,COX5A,CCND2,INS2,DAZAP2,GCG,ATP5F1,GM2A,R...
# GO:0043229                5  KLF6,COX5A,CCND2,INS2,DAZAP2,GCG,ATP5F1,GM2A,R...
# GO:0043226                2  KLF6,COX5A,CCND2,INS2,DAZAP2,GCG,ATP5F1,GM2A,C...
# ...                     ...                                                ...
# HP:0011970                2                                APOE,ITM2B,APP,CST3
# TF:M00801_1               1  ATP5D,DUSP3,SLC3A2,D8ERTD738E,UBE2B,BTG2,PRKAR...
# GO:0002483                1                       TAPBP,B2M,H2-K1,H2-T23,H2-D1
# GO:0034663                6                     HSP90B1,SDF2L1,P4HB,HSPA5,PPIB
# GO:0008250                1                       DAD1,RPN2,DDOST,OST4,KRTCAP2
#
# [1699 rows x 14 columns]

# %%
enrichment24 = gprofiler(facs24m, organism='mmusculus')

# %%
enrichment24.sort_values('p.value')
# Out:
#             query.number  significant        p.value  term.size  query.size  \
# term.id
# GO:0005737             1         True  5.060000e-110      10422         837
# GO:0044444             1         True  1.030000e-109       8155         837
# GO:0044424             1         True  6.910000e-103      13275         837
# GO:0043229             1         True   5.830000e-95      11660         837
# GO:0043226             1         True   4.610000e-94      11903         837
# ...                  ...          ...            ...        ...         ...
# GO:0002478             1         True   4.820000e-02         16         837
# GO:0032409             1         True   4.820000e-02        256         837
# GO:0033178             1         True   4.820000e-02         16         837
# GO:0051962             1         True   4.860000e-02        588         837
# HP:0011970             1         True   4.960000e-02          5         206
#
#             overlap.size  recall  precision     term.id domain  \
# term.id
# GO:0005737           706   0.843      0.068  GO:0005737     CC
# GO:0044444           626   0.748      0.077  GO:0044444     CC
# GO:0044424           778   0.930      0.059  GO:0044424     CC
# GO:0043229           725   0.866      0.062  GO:0043229     CC
# GO:0043226           731   0.873      0.061  GO:0043226     CC
# ...                  ...     ...        ...         ...    ...
# GO:0002478             6   0.007      0.375  GO:0002478     BP
# GO:0032409            25   0.030      0.098  GO:0032409     BP
# GO:0033178             6   0.007      0.375  GO:0033178     CC
# GO:0051962            44   0.053      0.075  GO:0051962     BP
# HP:0011970             4   0.019      0.800  HP:0011970     hp
#
#             subgraph.number  \
# term.id
# GO:0005737              131
# GO:0044444              131
# GO:0044424              131
# GO:0043229              131
# GO:0043226              131
# ...                     ...
# GO:0002478               65
# GO:0032409               65
# GO:0033178              131
# GO:0051962               65
# HP:0011970              319
#
#                                                     term.name  relative.depth  \
# term.id
# GO:0005737                                          cytoplasm               5
# GO:0044444                                   cytoplasmic part               6
# GO:0044424                                 intracellular part               4
# GO:0043229                            intracellular organelle               5
# GO:0043226                                          organelle               2
# ...                                                       ...             ...
# GO:0002478        antigen processing and presentation of e...               4
# GO:0032409                 regulation of transporter activity               3
# GO:0033178        proton-transporting two-sector ATPase co...               4
# GO:0051962         positive regulation of nervous system d...               5
# HP:0011970                        Cerebral amyloid angiopathy               1
#
#                                                  intersection
# term.id
# GO:0005737  GNAI3,CAV2,COX5A,INS2,DAZAP2,GCG,ATP5F1,HNRNPD...
# GO:0044444  GNAI3,CAV2,COX5A,INS2,GCG,ATP5F1,HNRNPD,GM2A,H...
# GO:0044424  GNAI3,CAV2,COX5A,INS2,DAZAP2,GCG,ATP5F1,HNRNPD...
# GO:0043229  GNAI3,CAV2,COX5A,INS2,DAZAP2,GCG,ATP5F1,HNRNPD...
# GO:0043226  GNAI3,CAV2,COX5A,INS2,DAZAP2,GCG,ATP5F1,HNRNPD...
# ...                                                       ...
# GO:0002478                 CD74,H2-AA,FCER1G,B2M,H2-K1,H2-AB1
# GO:0032409  INS2,CALM1,UBQLN1,KIF5B,FXYD5,PTEN,YWHAH,PPP2C...
# GO:0033178           ATP5D,ATP6V1F,ATP5E,ATP6AP1,ATP5B,ATP5C1
# GO:0051962  RAC1,APOE,HSPB1,EIF4G2,CTNNB1,RHOA,PTEN,TIMP2,...
# HP:0011970                                APOE,ITM2B,APP,CST3
#
# [1723 rows x 14 columns]
