# %%
# age all genes comparison
# jul28

# %%
import scanpy as sc
import pandas as pd
import numpy as np
sc.settings.verbosity=3

# %%
import seaborn as sns
import sys

import matplotlib.pyplot as plt
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42

# show figures in the notebook
# %matplotlib inline

# %%
cd /users/madelinepark/downloads
# Out:
# /Users/madelinepark/Downloads

# %%
facs3= pd.read_csv('facsAllGenes3m.csv')
facs18= pd.read_csv('facsAllGenes18m.csv')
facs24= pd.read_csv('facsAllGenes24m.csv')
facs3m = list(facs3['3m'])
facs18m = list(facs18['18m'])
facs24m = list(facs24['24m'])

# %%
# facs3m

# %%
from venn import pseudovenn
from venn import venn

# %%
ageComparison = {
    'facs3':set(facs3['3m']),
    'facs18':set(facs18['18m']),
    'facs24':set(facs24['24m'])
}

# %%
venn(ageComparison)

# %%
unique3facs = [ele for ele in facs3m if ele not in facs18m]
unique3facs = [ele for ele in facs3m if ele not in facs24m]

unique18facs = [el for el in facs18m if el not in facs3m]
unique18facs = [el for el in facs18m if el not in facs24m]

unique24facs = [e for e in facs24m if e not in facs3m]
unique24facs = [e for e in facs24m if e not in facs18m]

# %%
unique3facs
# Out:
# ['Mgp',
#  'Gm6548',
#  'Lum',
#  'Bcl7c',
#  'Crlf2',
#  '1810030J14Rik',
#  'Ptgds',
#  '4930413G21Rik',
#  'Iapp',
#  'Ccdc80',
#  'Dpt',
#  'Fbln1',
#  'Serping1',
#  'Gadd45gip1',
#  'Col1a2',
#  'Sf3b4',
#  'Znhit1',
#  'Car1',
#  'Gm20594',
#  'Chga',
#  'S100a14',
#  'C1qb',
#  'Anapc11',
#  'Ppp1r35',
#  'Ngp',
#  'Pcsk1n',
#  'Tmem119',
#  'Nisch',
#  'Arrb2',
#  'Krt8',
#  'Apc',
#  'Fcrls',
#  'Tnfsf12',
#  'Cd79a',
#  'Errfi1',
#  'Copa',
#  'C1qc',
#  'Ppy',
#  'Slc38a2',
#  'Fkbp2',
#  'Sfn',
#  'Krt5',
#  'Klf5',
#  'Cpe',
#  'Nme7',
#  'Inmt',
#  'Gpr34',
#  'Obfc2b',
#  'Igfbp7',
#  'C3',
#  '2210415F13Rik',
#  'Snrpe',
#  'Wbp2',
#  'Arl8a',
#  'Clec3b',
#  'Glg1',
#  'Abi3',
#  'Sf3b1',
#  'Olfr613',
#  'Akt1s1',
#  'Siglech',
#  'Cxcl14',
#  'Cx3cr1',
#  'Rbm26',
#  'Fus',
#  'Cd36',
#  'Nr1d1',
#  'Rac2',
#  'Ssr1',
#  'Adrm1',
#  'Mag',
#  'Cytip',
#  'Sparcl1',
#  'S1pr1',
#  'S100a16',
#  'Ecm1',
#  'Nfic',
#  'Cd24a',
#  'Aldoart1',
#  'Morf4l2',
# ...

# %%
unique18facs
# Out:
# ['Iapp',
#  'Mgp',
#  'Gm6548',
#  'Chga',
#  'Anapc11',
#  '1810030J14Rik',
#  'Lum',
#  'Ppy',
#  'Beta-s',
#  'Serping1',
#  'Dpt',
#  'Ccdc80',
#  'C1qb',
#  'Gadd45gip1',
#  'Pyy',
#  'Krt8',
#  'Sf3b4',
#  'Fbln1',
#  'Znhit1',
#  'Fkbp2',
#  'Bcl7c',
#  'Scg2',
#  'Manf',
#  'Sf3a2',
#  '4930413G21Rik',
#  'C1qc',
#  'Rbm26',
#  'Fabp4',
#  'Cpe',
#  'Epcam',
#  'Mtch1',
#  'Furin',
#  'Crlf2',
#  'Zfp691',
#  'Sst',
#  'Col1a2',
#  'Csda',
#  'Igfbp7',
#  '1100001G20Rik',
#  'Wbp2',
#  'Sdf2l1',
#  'Sf3b1',
#  'Slc38a2',
#  'Arrb2',
#  'Arl8a',
#  'Polr2a',
#  '1700023F06Rik',
#  'Cd79a',
#  'Ssr1',
#  'Pcsk1n',
#  'Krt5',
#  'Lgals3bp',
#  'Sfn',
#  'Rad23b',
#  'Mir692-1',
#  'Cd24a',
#  'Nr1d1',
#  'Eif3e',
#  'Wbp5',
#  'Cldn4',
#  'Ppp1r35',
#  'Mtdh',
#  'C330021F23Rik',
#  'Spcs2',
#  'Rac2',
#  'Glrx3',
#  'Crip2',
#  'Cxcl1',
#  'Nisch',
#  'Tspan7',
#  'Arpp19',
#  'Nfic',
#  'Eif3a',
#  'Ddost',
#  'Fus',
#  'Herpud1',
#  'Bcap31',
#  'Morf4l2',
#  'Errfi1',
# ...

# %%
unique24facs
# Out:
# ['Ppp1cb',
#  'Erbb2ip',
#  'Tm9sf3',
#  'Sfpq',
#  'Ptp4a1',
#  'Dync1i2',
#  'Map3k1',
#  'Nufip2',
#  'Amfr',
#  'Gpbp1l1',
#  'Picalm',
#  'Stt3a',
#  'Tmem123',
#  'Vps35',
#  'Srp54a',
#  'Gpbp1',
#  'Caprin1',
#  'Taok1',
#  '4931408D14Rik',
#  'Snd1',
#  'Jmjd1c',
#  'Prpf4b',
#  'Skiv2l2',
#  'Calu',
#  'Smg7',
#  'Plekhb1',
#  'Matr3',
#  'Pdia4',
#  'Rbm15',
#  'Capza1',
#  'Cnn3',
#  'Ddx6',
#  'Dcaf6',
#  'Dst',
#  'Usp9x',
#  'Pros1',
#  'Rpn1',
#  'Golph3',
#  'Itm2a',
#  'Ifnar1',
#  '2900053A13Rik',
#  'Ptn',
#  'Satb1',
#  'Hist1h1e',
#  'Hsph1',
#  'Ncoa4',
#  'Hspa9',
#  'Krt7',
#  'Arhgef1',
#  'Hnrnph2',
#  'Sell',
#  'Rtn3',
#  'Top2b',
#  'Mknk2',
#  'P4ha1',
#  'Rab6a',
#  'Adh1',
#  'Rnf13',
#  'Bzw1',
#  'Ctbp1',
#  'Thrap3',
#  '2400001E08Rik',
#  'Tmem30a',
#  'Mbnl2',
#  'Ube2h',
#  'Arcn1',
#  'Cmtm6',
#  'Arid1b',
#  'Cnp',
#  'Nmt1',
#  'Eif2s2',
#  'Mobp',
#  'Sox10',
#  'Sun2',
#  'Tcf7l2',
#  'Mtmr2',
#  'Ubl3',
#  'Lbr',
#  'Stag2',
#  'Gsto1',
# ...

# %%
facs3no24 = [ele for ele in facs3m if ele not in facs24m]
facs3no24
# Out:
# ['Mgp',
#  'Gm6548',
#  'Lum',
#  'Bcl7c',
#  'Crlf2',
#  '1810030J14Rik',
#  'Ptgds',
#  '4930413G21Rik',
#  'Iapp',
#  'Ccdc80',
#  'Dpt',
#  'Fbln1',
#  'Serping1',
#  'Gadd45gip1',
#  'Col1a2',
#  'Sf3b4',
#  'Znhit1',
#  'Car1',
#  'Gm20594',
#  'Chga',
#  'S100a14',
#  'C1qb',
#  'Anapc11',
#  'Ppp1r35',
#  'Ngp',
#  'Pcsk1n',
#  'Tmem119',
#  'Nisch',
#  'Arrb2',
#  'Krt8',
#  'Apc',
#  'Fcrls',
#  'Tnfsf12',
#  'Cd79a',
#  'Errfi1',
#  'Copa',
#  'C1qc',
#  'Ppy',
#  'Slc38a2',
#  'Fkbp2',
#  'Sfn',
#  'Krt5',
#  'Klf5',
#  'Cpe',
#  'Nme7',
#  'Inmt',
#  'Gpr34',
#  'Obfc2b',
#  'Igfbp7',
#  'C3',
#  '2210415F13Rik',
#  'Snrpe',
#  'Wbp2',
#  'Arl8a',
#  'Clec3b',
#  'Glg1',
#  'Abi3',
#  'Sf3b1',
#  'Olfr613',
#  'Akt1s1',
#  'Siglech',
#  'Cxcl14',
#  'Cx3cr1',
#  'Rbm26',
#  'Fus',
#  'Cd36',
#  'Nr1d1',
#  'Rac2',
#  'Ssr1',
#  'Adrm1',
#  'Mag',
#  'Cytip',
#  'Sparcl1',
#  'S1pr1',
#  'S100a16',
#  'Ecm1',
#  'Nfic',
#  'Cd24a',
#  'Aldoart1',
#  'Morf4l2',
# ...

# %%
facs24no3 = [ele for ele in facs24m if ele not in facs3m]
facs24no3
# Out:
# ['Erdr1',
#  'Tmf1',
#  'Ube2d2',
#  'Midn',
#  'Polr2l',
#  'Fam100b',
#  'Pafah1b1',
#  'Anp32a',
#  'Smg7',
#  'Pdia4',
#  'Gm6402',
#  'Eno1',
#  'Sephs2',
#  'Gatm',
#  'Slc2a1',
#  'Dcaf6',
#  'Fli1',
#  '1810027O10Rik',
#  'Dusp6',
#  'Upf1',
#  'St13',
#  'Ifnar1',
#  'Syngr2',
#  'Ptn',
#  'Atp5c1',
#  'Hsph1',
#  'Hspa9',
#  'Rnasek',
#  'Krt7',
#  'Arhgef1',
#  'Hnrnph2',
#  'Rtn3',
#  'Rps15a-ps6',
#  'Pitpnc1',
#  'Mknk2',
#  'P4ha1',
#  '1110003E01Rik',
#  'Vapa',
#  'Ctbp1',
#  'Thrap3',
#  'Mdh1',
#  'Skil',
#  'Ube2h',
#  'Arcn1',
#  'Map1lc3b',
#  'Stip1',
#  'Cyb5',
#  'Tmem66',
#  'Ppib',
#  'Sox10',
#  'Hmgn2',
#  'Sep15',
#  'Mtmr2',
#  'Scp2',
#  'Gigyf1',
#  'Ube2b',
#  'Hist1h2bc',
#  'Ubl3',
#  'Fkbp4',
#  'Pdia6',
#  'Xbp1',
#  'Sp3',
#  'Ndfip1',
#  'Mtus1',
#  'Atp6ap1',
#  'C030046I01Rik',
#  'Entpd1',
#  'Tra2b',
#  'Ifi30',
#  'Ppp1r15a',
#  'Uqcrc1',
#  'Actn4',
#  'Ndufs5',
#  'Tmed3',
#  'Ypel3',
#  'Rab1',
#  'Cct6a',
#  'Rab18',
#  'Atp6v1g1',
# ...
