# %%
# age all genes comparison
# jul28

# %%
import scanpy as sc
import pandas as pd
import numpy as np
sc.settings.verbosity=3

# %%
import seaborn as sns
import sys

import matplotlib.pyplot as plt
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42

# show figures in the notebook
# %matplotlib inline

# %%
cd /users/madelinepark/downloads
# Out:
# /Users/madelinepark/Downloads

# %%
facs3= pd.read_csv('facsAllGenes3m.csv')
facs18= pd.read_csv('facsAllGenes18m.csv')
facs24= pd.read_csv('facsAllGenes24m.csv')
facs3m = facs3['3m']
facs18m = facs18['18m']
facs24m = facs24['24m']

# %%
facs18m
# Out:
# 0       Gm6981
# 1        Lars2
# 2         Cfl1
# 3       Tmsb10
# 4          Dcn
#         ...
# 917       Ubr4
# 918      Cldn5
# 919        Spr
# 920     Cxcl14
# 921    Gm10012
# Name: 18m, Length: 922, dtype: object

# %%
from venn import pseudovenn
from venn import venn

# %%
ageComparison = {
    'facs3':set(facs3['3m']),
    'facs18':set(facs18['18m']),
    'facs24':set(facs24['24m'])
}

# %%
venn(ageComparison)

# %%
unique3facs = [ele for ele in facs3m if ele not in facs18m]
unique3facs = [ele for ele in facs3m if ele not in facs24m]

unique18facs = [ele for ele in facs18m if ele not in facs3m]
unique18facs = [ele for ele in facs18m if ele not in facs24m]

unique24facs = [ele for ele in facs24m if ele not in facs3m]
unique24facs = [ele for ele in facs24m if ele not in facs18m]

# %%
# unique3facs

# %%
# unique18facs

# %%
# unique24facs
# gm6981

# %%
names_to_remove = set([facs3m for r in facs3m if not facs18m])
# filtered_list = [r for r in o2m_links if r.rel.through._meta.object_name in names_to_remove]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-2e3d0da8fbc3> in <module>
# ----> 1 names_to_remove = set([facs3m for r in facs3m if not facs18m])
#       2 # filtered_list = [r for r in o2m_links if r.rel.through._meta.object_name in names_to_remove]
#
# <ipython-input-45-2e3d0da8fbc3> in <listcomp>(.0)
# ----> 1 names_to_remove = set([facs3m for r in facs3m if not facs18m])
#       2 # filtered_list = [r for r in o2m_links if r.rel.through._meta.object_name in names_to_remove]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1477     def __nonzero__(self):
#    1478         raise ValueError(
# -> 1479             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1480             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1481         )
#
# ...
