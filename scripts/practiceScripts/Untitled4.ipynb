# %%
import scanpy as sc
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-0074c9bc0b31> in <module>
# ----> 1 import scanpy as sc
#
# ~/opt/anaconda3/lib/python3.7/site-packages/scanpy/__init__.py in <module>
#      34 # the actual API
#      35 from ._settings import settings, Verbosity  # start with settings as several tools are using it
# ---> 36 from . import tools as tl
#      37 from . import preprocessing as pp
#      38 from . import plotting as pl
#
# ~/opt/anaconda3/lib/python3.7/site-packages/scanpy/tools/__init__.py in <module>
# ----> 1 from ..preprocessing import pca
#       2 from ._tsne import tsne
#       3 from ._umap import umap
#       4 from ._diffmap import diffmap
#       5 from ._draw_graph import draw_graph
#
# ~/opt/anaconda3/lib/python3.7/site-packages/scanpy/preprocessing/__init__.py in <module>
# ----> 1 from ._recipes import recipe_zheng17, recipe_weinreb17, recipe_seurat
#       2 from ._simple import filter_cells, filter_genes
#       3 from ._deprecated.highly_variable_genes import filter_genes_dispersion
#       4 from ._highly_variable_genes import highly_variable_genes
#       5 from ._simple import log1p, sqrt, scale, subsample
#
# ~/opt/anaconda3/lib/python3.7/site-packages/scanpy/preprocessing/_recipes.py in <module>
#       4 from anndata import AnnData
#       5
# ----> 6 from . import _simple as pp
#       7 from ._deprecated.highly_variable_genes import filter_genes_dispersion, filter_genes_cv_deprecated
#       8 from ._normalization import normalize_total
#
# ~/opt/anaconda3/lib/python3.7/site-packages/scanpy/preprocessing/_simple.py in <module>
#      12 import scipy as sp
#      13 from scipy.sparse import issparse, isspmatrix_csr, csr_matrix, spmatrix
# ---> 14 from sklearn.utils import sparsefuncs, check_array
#      15 from pandas.api.types import is_categorical_dtype
#      16 from anndata import AnnData
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/__init__.py in <module>
#      80     from . import _distributor_init  # noqa: F401
#      81     from . import __check_build  # noqa: F401
# ---> 82     from .base import clone
#      83     from .utils._show_versions import show_versions
#      84
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/base.py in <module>
#      18
#      19 from . import __version__
# ---> 20 from .utils import _IS_32BIT
#      21
#      22 _DEFAULT_TAGS = {
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/__init__.py in <module>
#      25 from ..exceptions import DataConversionWarning
#      26 from .deprecation import deprecated
# ---> 27 from .fixes import np_version
#      28 from .validation import (as_float_array,
#      29                          assert_all_finite,
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/fixes.py in <module>
#      16 import scipy.sparse as sp
#      17 import scipy
# ---> 18 import scipy.stats
#      19 from scipy.sparse.linalg import lsqr as sparse_lsqr  # noqa
#      20
#
# ~/opt/anaconda3/lib/python3.7/site-packages/scipy/stats/__init__.py in <module>
#     386
#     387 """
# --> 388 from .stats import *
#     389 from .distributions import *
#     390 from .morestats import *
#
# ~/opt/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py in <module>
#     172 from numpy import array, asarray, ma
#     173
# --> 174 from scipy.spatial.distance import cdist
#     175 from scipy.ndimage import measurements
#     176 from scipy._lib._util import (_lazywhere, check_random_state, MapWrapper,
#
# ~/opt/anaconda3/lib/python3.7/site-packages/scipy/spatial/__init__.py in <module>
#      99 from ._spherical_voronoi import SphericalVoronoi
#     100 from ._plotutils import *
# --> 101 from ._procrustes import procrustes
#     102 from ._geometric_slerp import geometric_slerp
#     103
#
# ~/opt/anaconda3/lib/python3.7/site-packages/scipy/spatial/_procrustes.py in <module>
#       7
#       8 import numpy as np
# ----> 9 from scipy.linalg import orthogonal_procrustes
#      10
#      11
#
# ~/opt/anaconda3/lib/python3.7/site-packages/scipy/linalg/__init__.py in <module>
#     210 from ._procrustes import *
#     211 from ._decomp_update import *
# --> 212 from ._sketches import *
#     213 from ._decomp_cossin import *
#     214
#
# ~/opt/anaconda3/lib/python3.7/site-packages/scipy/linalg/_sketches.py in <module>
#       6 import numpy as np
#       7
# ----> 8 from scipy._lib._util import check_random_state, rng_integers
#       9 from scipy.sparse import csc_matrix
#      10
#
# ImportError: cannot import name 'rng_integers' from 'scipy._lib._util' (/Users/madelinepark/opt/anaconda3/lib/python3.7/site-packages/scipy/_lib/_util.py)

# %%
# Imports 
import numpy as np
import pandas as pd
import scanpy as sc
import random
from anndata import read_h5ad
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import accuracy_score
from sklearn.feature_selection import RFE
from sklearn.feature_selection import RFECV
import seaborn as sns
import matplotlib.pyplot as plt
import scanpy.external as sce
import logging as logg
# Out:
# /Users/madelinepark/opt/anaconda3/lib/python3.7/site-packages/anndata/base.py:15: FutureWarning: pandas.core.index is deprecated and will be removed in a future version.  The public classes are available in the top-level namespace.
#   from pandas.core.index import RangeIndex
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-12e377649061> in <module>
#       2 import numpy as np
#       3 import pandas as pd
# ----> 4 import scanpy as sc
#       5 import random
#       6 from anndata import read_h5ad
#
# ~/opt/anaconda3/lib/python3.7/site-packages/scanpy/__init__.py in <module>
#       1 # some technical stuff
#       2 import sys
# ----> 3 from ._utils import pkg_version, check_versions, annotate_doc_types
#       4
#       5 __author__ = ', '.join([
#
# ~/opt/anaconda3/lib/python3.7/site-packages/scanpy/_utils.py in <module>
#      15 import numpy as np
#      16 from numpy import random
# ---> 17 from anndata import AnnData
#      18 from textwrap import dedent
#      19 from packaging import version
#
# ~/opt/anaconda3/lib/python3.7/site-packages/anndata/__init__.py in <module>
# ----> 1 from .base import AnnData, _MAIN_NARRATIVE
#       2 from .readwrite import (
#       3     read_h5ad, read_loom, read_hdf,
#       4     read_excel, read_umi_tools,
#       5     read_csv, read_text, read_mtx,
#
# ~/opt/anaconda3/lib/python3.7/site-packages/anndata/base.py in <module>
#      38             return 'mock zappy.base.ZappyArray'
#      39
# ---> 40 from . import h5py
#      41 from .layers import AnnDataLayers
#      42
#
# ~/opt/anaconda3/lib/python3.7/site-packages/anndata/h5py/__init__.py in <module>
#      22    SparseDataset
#      23 """
# ---> 24 from .h5sparse import File, Group, SparseDataset, _load_h5_dataset_as_sparse
#      25 from h5py import Dataset, special_dtype
#      26
#
# ~/opt/anaconda3/lib/python3.7/site-packages/anndata/h5py/h5sparse.py in <module>
#      10 from scipy.sparse.sputils import IndexMixin
#      11
# ---> 12 from ..compat import PathLike
#      13
#      14 from .utils import _chunked_rows
#
# ImportError: cannot import name 'PathLike' from 'anndata.compat' (/Users/madelinepark/opt/anaconda3/lib/python3.7/site-packages/anndata/compat/__init__.py)
