# %%
Venn Diagram Comparisons
# https://github.com/LankyCyril/pyvenn/blob/master/pyvenn-demo.ipynb

# %%
import numpy as np
import pandas as pd
import scanpy as sc
from anndata import read_h5ad
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import accuracy_score
from sklearn.feature_selection import RFE
from matplotlib import pyplot as plt


sc.settings.verbosity = 3             # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.logging.print_versions()
# Out:
# scanpy==1.5.1 anndata==0.7.3 umap==0.4.4 numpy==1.18.1 scipy==1.5.0 pandas==1.0.1 scikit-learn==0.22.1 statsmodels==0.11.0

# %%
import matplotlib_venn

# %%
from venn import venn6
from venn import get_labels
from venn import pseudovenn

# %% [markdown]
# ## droplet nEstimators comparison

# %%
droplet50 = pd.read_csv('/Users/madelinepark/desktop/results_madeline_leela/50_droplet_tfs_age.csv')
droplet100 = pd.read_csv('/Users/madelinepark/desktop/results_madeline_leela/100_droplet_tfs_age.csv')
droplet500 = pd.read_csv('/Users/madelinepark/desktop/results_madeline_leela/500_droplet_tfs_age.csv')
droplet1000 = pd.read_csv('/Users/madelinepark/desktop/results_madeline_leela/1000_droplet_tfs_age.csv')
droplet2000 = pd.read_csv('/Users/madelinepark/desktop/results_madeline_leela/2000_droplet_tfs_age.csv')
droplet5000 = pd.read_csv('/Users/madelinepark/desktop/results_madeline_leela/senis_wholedroplet_tfs_age_5000.csv')
# one option is to make these all a dictionary for headers and values, then call 'venn'

# %%
dropletDict1m = {
    "50Nestimators": set(droplet50['1m'][0:300]),
    "100Nestimators": set(droplet100['1m'][0:300]),
    "500Nestimators": set(droplet500['1m'][0:300]),
    "1000Nestimators": set(droplet1000['1m'][0:300]),
    "2000Nestimators": set(droplet2000['1m'][0:300]),
    "5000Nestimators": set(droplet5000['1m'][0:300])
    
}
#set is annoying bc it automatically sorts

# %%
venn(dropletDict3m)

# %%
# set(droplet100['3m'])
pseudovenn(dropletDict1m)

# %% [markdown]
# ## facs nEstimators comparison

# %%
facs50 = pd.read_csv('/Users/madelinepark/desktop/results_madeline_leela/50_facs_tfs_age.csv')
facs100 = pd.read_csv('/Users/madelinepark/desktop/results_madeline_leela/100_facs_tfs_age.csv')
facs500 = pd.read_csv('/Users/madelinepark/desktop/results_madeline_leela/500_facs_tfs_age.csv')
facs1000 = pd.read_csv('/Users/madelinepark/desktop/results_madeline_leela/1000_facs_tfs_age.csv')
facs2000 = pd.read_csv('/Users/madelinepark/desktop/results_madeline_leela/2000_facs_tfs_age.csv')
facs5000 = pd.read_csv('/Users/madelinepark/desktop/results_madeline_leela/senis_wholefacs_tfs_age_5000 (1).csv')
# one option is to make these all a dictionary for headers and values, then call 'venn'

# %%
facsDict3m = {
    "50Nestimators": set(facs50['3m'][0:300]),
    "100Nestimators": set(facs100['3m'][0:300]),
    "500Nestimators": set(facs500['3m'][0:300]),
    "1000Nestimators": set(facs1000['3m'][0:300]),
    "2000Nestimators": set(facs2000['3m'][0:300]),
    "5000Nestimators": set(facs5000['3m'][0:300])
}
#set is annoying bc it automatically sorts

# %%
venn(facsDict3m)

# %% [markdown]
# ## droplet facs comparison

# %%
dropletfacs3m = {
    
    
}
