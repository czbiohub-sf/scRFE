# %%
from scRFE.scRFE import scRFE
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~/anaconda3/envs/scanpytest/lib/python3.6/site-packages/numpy/core/__init__.py in <module>
#      39 try:
# ---> 40     from . import multiarray
#      41 except ImportError as exc:
#
# ~/anaconda3/envs/scanpytest/lib/python3.6/site-packages/numpy/core/multiarray.py in <module>
#      11
# ---> 12 from . import overrides
#      13 from . import _multiarray_umath
#
# ~/anaconda3/envs/scanpytest/lib/python3.6/site-packages/numpy/core/overrides.py in <module>
#       5
# ----> 6 from numpy.core._multiarray_umath import (
#       7     add_docstring, implement_array_function, _get_implementing_args)
#
# ImportError: dlopen(/Users/madelinepark/anaconda3/envs/scanpytest/lib/python3.6/site-packages/numpy/core/_multiarray_umath.cpython-36m-darwin.so, 2): Library not loaded: @rpath/libcblas.3.dylib
# ...
