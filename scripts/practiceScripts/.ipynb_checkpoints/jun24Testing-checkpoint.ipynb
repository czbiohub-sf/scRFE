# %% [markdown]
# # WedJune24 scRFE PyPI Testing

# %%
from scRFE.scRFE import scRFE

# %%
from anndata import read_h5ad
adataLiver = read_h5ad('/Users/madelinepark/Downloads/Liver_droplet.h5ad')

# %%
scRFE (adata = adataLiver, classOfInterest = 'age')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-f05cc184ba22> in <module>
# ----> 1 scRFE (adata = adataLiver, classOfInterest = 'age')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/scRFE/scRFE.py in scRFE(adata, classOfInterest, nEstimators, randomState, nJobs, oobScore, Step, Cv)
#     263         feature_selected, feature_importance = makeOneForest(dataMatrix_labelOfInterest,
#     264                                                              classOfInterest,
# --> 265                                     labelOfInterest = labelOfInterest)
#     266
#     267         results_df = resultWrite (classOfInterest, results_df,
#
# ~/opt/anaconda3/lib/python3.7/site-packages/scRFE/scRFE.py in makeOneForest(dataMatrix, classOfInterest, labelOfInterest, nEstimators, randomState, nJobs, oobScore, Step, Cv)
#     171
#     172     """
# ...
