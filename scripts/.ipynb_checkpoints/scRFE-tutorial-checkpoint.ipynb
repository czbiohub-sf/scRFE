# %% [markdown]
# # scRFE Tutorial

# %% [markdown]
# Here we present an example of how to use scRFE. We analyze the Limb Muscle Facs data from the Tabula-Muris-Senis dataset that is available on Figshare. We split the data by age.

# %% [markdown]
# More features were selected than ideal in this model, because we used a very small number of estimators and a low CV score, for time's sake. This results are not accurate though, and we recommend running the code with 1000 estimators and CV>=5 with an EC2 instance.

# %% [markdown]
# ### Imports

# %%
# Imports 
import numpy as np
import pandas as pd
import scanpy as sc
from anndata import read_h5ad
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import accuracy_score
from sklearn.feature_selection import RFE
from sklearn.feature_selection import RFECV

# %% [markdown]
# ### Read in anndata file

# %%
cd
# Out:
# /Users/madelinepark

# %%
# read in data and NORMALIZE
adata = read_h5ad('/Users/madelinepark/Downloads/Kidney_facs.h5ad')
sc.pp.normalize_total(adata, target_sum = 1e5, inplace = True)
# log it after
sc.pp.log1p(adata)
tiss = adata

# %%
cd /Users/madelinepark/Desktop
# Out:
# /Users/madelinepark/Desktop

# %% [markdown]
# ### Run scRFE one vs all classification for age

# %%
results_age_cv = pd.DataFrame() #create results data frame 

for c in list(set(tiss.obs['age'])): 
    print(c)
    age_of_interest = c
    tiss.obs['age_type_of_interest'] = 'rest' #moved into, was outside before
    tiss.obs.loc[tiss.obs['age'] == age_of_interest,'age_type_of_interest'] = age_of_interest

    clf = RandomForestClassifier(n_estimators=1000, random_state=0, n_jobs=-1, oob_score=True)
    selector = RFECV(clf, step=0.2, cv=3, n_jobs=4) # step = % rounded down at each iteration  
    
# #     tiss.obs.loc[tiss.obs[tiss.obs['age'] == age_of_interest].index,'age_type_of_interest'] = age_of_interest
#     tiss.obs.loc[tiss.obs['age'] == age_of_interest,'age_type_of_interest'] = age_of_interest

    feat_labels = tiss.var_names 
    X = tiss.X
    y = tiss.obs['age_type_of_interest']
    
    print('training...')
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05, random_state=0) 
    print(type(X_train))
    print(type(y_train))
    clf.fit(X_train, y_train)
    selector.fit(X_train, y_train)
    feature_selected = feat_labels[selector.support_] 
    
    print('result writing')
    column_headings = []
    column_headings.append(c)
    column_headings.append(c + '_gini')
    
    resaux = pd.DataFrame(columns=column_headings)
    resaux[c] = feature_selected
    resaux[c + '_gini'] = (selector.estimator_.feature_importances_)
    
    print(feature_selected)
    print (selector.estimator_.feature_importances_)
    
    results_age_cv = pd.concat([results_age_cv,resaux],axis=1)
    
    tiss.obs['age_type_of_interest'] = 'rest'
    
results_age_cv
# Out:
# 3m
# training...
# <class 'scipy.sparse.csr.csr_matrix'>
# <class 'pandas.core.series.Series'>
# result writing
# Index(['0610005C13Rik', '0610007C21Rik', '0610007L01Rik', '0610007N19Rik',
#        '0610009D07Rik', '0610010F05Rik', '0610010K14Rik', '0610010O12Rik',
#        '0610011F06Rik', '0610012H03Rik',
#        ...
#        'Zmym5', 'Zmynd11', 'Zmynd8', 'Znhit1', 'Znrf1', 'Znrf2', 'Zranb2',
#        'Zrsr2', 'Zyg11b', 'Zyx'],
#       dtype='object', name='index', length=4583)
# [7.49444592e-05 6.04288944e-05 3.46449252e-05 ... 4.67854418e-05
# 4559         Zfp664  0.000055         Zfp664  0.000055
# 4560         Zfp706  0.000108         Zfp706  0.000108
# 4561         Zfp710  0.000060         Zfp710  0.000060
# 4562         Zfp771  0.000055         Zfp771  0.000055
# 4563         Zfp800  0.000040         Zfp800  0.000040
# 4564         Zfp865  0.000017         Zfp865  0.000017
# 4565         Zfp952  0.000016         Zfp952  0.000016
# 4566          Zfpl1  0.000120          Zfpl1  0.000120
# 4567            Zfr  0.000103            Zfr  0.000103
# 4568        Zfyve21  0.000061        Zfyve21  0.000061
# 4569           Zg16  0.003549           Zg16  0.003549
# 4570          Zmat5  0.000093          Zmat5  0.000093
# 4571          Zmiz1  0.000084          Zmiz1  0.000084
# 4572       Zmpste24  0.000051       Zmpste24  0.000051
# 4573          Zmym5  0.000090          Zmym5  0.000090
# 4574        Zmynd11  0.000036        Zmynd11  0.000036
# 4575         Zmynd8  0.000101         Zmynd8  0.000101
# 4576         Znhit1  0.000073         Znhit1  0.000073
# 4577          Znrf1  0.000130          Znrf1  0.000130
# 4578          Znrf2  0.000070          Znrf2  0.000070
# 4579         Zranb2  0.000038         Zranb2  0.000038
# 4580          Zrsr2  0.000047          Zrsr2  0.000047
# 4581         Zyg11b  0.000055         Zyg11b  0.000055
# 4582            Zyx  0.000049            Zyx  0.000049
#
# [4583 rows x 4 columns]

# %%
results_age_cv.to_csv('KidneyTutorialAge1000.csv')

# %%
cd scRFE\ kidney\ 1000\ V1\ results\ and\ to\ compare
# Out:
# /Users/madelinepark/Desktop/scRFE kidney 1000 V1 results and to compare

# %%
testRez = pd.read_csv('KidneyTutorialAge1000.csv')

# %%
testRez.sort_values(by = '24m_gini', ascending = False)
testRez.to_csv('KidneyTutorialAge1000SORTEDv1.csv')

# %% [markdown]
# ### Run scRFE one vs all classification for cell type

# %%
results_celltype_cv = pd.DataFrame() #create results data frame 

for c in list(set(tiss.obs['cell_ontology_class'])): 
    print(c)
    cell_of_interest = c
    tiss.obs['cell_type_of_interest'] = 'rest' #moved into, was outside before
    tiss.obs.loc[tiss.obs['cell_ontology_class'] == cell_of_interest,'cell_type_of_interest'] = cell_of_interest

    clf = RandomForestClassifier(n_estimators=1000, random_state=0, n_jobs=-1, oob_score=True)
    selector = RFECV(clf, step=0.2, cv=3, n_jobs=4) # step = % rounded down at each iteration  
    
# #     tiss.obs.loc[tiss.obs[tiss.obs['age'] == age_of_interest].index,'age_type_of_interest'] = age_of_interest
#     tiss.obs.loc[tiss.obs['age'] == age_of_interest,'age_type_of_interest'] = age_of_interest

    feat_labels = tiss.var_names 
    X = tiss.X
    y = tiss.obs['cell_type_of_interest']
    
    print('training...')
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05, random_state=0) 
    clf.fit(X_train, y_train)
    selector.fit(X_train, y_train)
    feature_selected = feat_labels[selector.support_] 
    
    print('result writing')
    column_headings = []
    column_headings.append(c)
    column_headings.append(c + '_gini')
    
    resaux = pd.DataFrame(columns=column_headings)
    resaux[c] = feature_selected
    resaux[c + '_gini'] = (selector.estimator_.feature_importances_)
    
    print(feature_selected)
    print (selector.estimator_.feature_importances_)
    
    results_celltype_cv = pd.concat([results_celltype_cv,resaux],axis=1)
    
    tiss.obs['cell_type_of_interest'] = 'rest'
    
results_celltype_cv
# Out:
# T cell
# training...

# %%
results_celltype_cv.to_csv('KidneyTutorialCelltype1000.csv')

# %% [markdown]
# ## Now doing exact same code above for kidney

# %%
adata = read_h5ad('/Users/madelinepark/Downloads/Kidney_facs.h5ad')
tiss = adata

# %%
results_celltype_cv = pd.DataFrame() #create results data frame 

for c in list(set(tiss.obs['cell_ontology_class'])): 
    print(c)
    cell_of_interest = c
    tiss.obs['cell_type_of_interest'] = 'rest' #moved into, was outside before
    tiss.obs.loc[tiss.obs['cell_ontology_class'] == cell_of_interest,'cell_type_of_interest'] = cell_of_interest

    clf = RandomForestClassifier(n_estimators=1000, random_state=0, n_jobs=-1, oob_score=True)
    selector = RFECV(clf, step=0.2, cv=3, n_jobs=4) # step = % rounded down at each iteration  
    
# #     tiss.obs.loc[tiss.obs[tiss.obs['age'] == age_of_interest].index,'age_type_of_interest'] = age_of_interest
#     tiss.obs.loc[tiss.obs['age'] == age_of_interest,'age_type_of_interest'] = age_of_interest

    feat_labels = tiss.var_names 
    X = tiss.X
    y = tiss.obs['cell_type_of_interest']
    
    print('training...')
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05, random_state=0) 
    clf.fit(X_train, y_train)
    selector.fit(X_train, y_train)
    feature_selected = feat_labels[selector.support_] 
    
    print('result writing')
    column_headings = []
    column_headings.append(c)
    column_headings.append(c + '_gini')
    
    resaux = pd.DataFrame(columns=column_headings)
    resaux[c] = feature_selected
    resaux[c + '_gini'] = (selector.estimator_.feature_importances_)
    
    print(feature_selected)
    print (selector.estimator_.feature_importances_)
    
    results_celltype_cv = pd.concat([results_celltype_cv,resaux],axis=1)
    
    tiss.obs['cell_type_of_interest'] = 'rest'
    
results_celltype_cv
# Out:
# Kidney-new-24m-cluster
# training...
# result writing
# Index(['Beta-s', 'Gm16861', 'Plin5', 'Sec14l3'], dtype='object', name='index')
# [0.45796539 0.173545   0.10231781 0.26617181]
# kidney loop of Henle ascending limb epithelial cell
# training...
# result writing
# Index(['Slc12a1'], dtype='object', name='index')
# [1.]
# fenestrated cell
# training...
# result writing
# Index(['0610007C21Rik', '0610007L01Rik', '0610007N19Rik', '0610007P14Rik',
#        '0610009D07Rik', '0610009O20Rik', '0610010K14Rik', '0610010O12Rik',
#        '0610011F06Rik', '0610012G03Rik',
#        ...
#        'Znfx1', 'Znhit1', 'Znhit6', 'Znrd1', 'Znrf1', 'Zpbp', 'Zranb1',
#        'Zswim6', 'Zw10', 'Zxdc'],
#       dtype='object', name='index', length=4583)
# [0.00000000e+00 0.00000000e+00 5.86593394e-05 ... 2.91909742e-05
#  0.00000000e+00 6.30596768e-05]
# mesangial cell
# training...
# result writing
# Index(['0610007C21Rik', '0610007L01Rik', '0610007N19Rik', '0610007P08Rik',
#        '0610007P14Rik', '0610007P22Rik', '0610008F07Rik', '0610009B14Rik',
#        '0610009B22Rik', '0610009D07Rik',
#        ...
#        'Znrf1', 'Znrf3', 'Zscan22', 'Zscan29', 'Zwilch', 'Zwint', 'Zxdc',
#        'Zyx', 'Zzz3', 'zsGreen_transgene'],
#       dtype='object', name='index', length=9162)
# [2.07160269e-05 8.22096357e-07 0.00000000e+00 ... 1.31602577e-04
#  0.00000000e+00 0.00000000e+00]
# B cell
# training...
# result writing
# Index(['Ccr7', 'Cd79a', 'Ly6d', 'Ms4a1'], dtype='object', name='index')
# [0.18917166 0.36055857 0.36892729 0.08134248]
# kidney collecting duct epithelial cell
# training...
# result writing
# Index(['0610005C13Rik', '0610007C21Rik', '0610007N19Rik', '0610007P14Rik',
#        '0610009D07Rik', '0610010K14Rik', '0610010O12Rik', '0610011F06Rik',
#        '0610012G03Rik', '0610012H03Rik',
#        ...
#        'Zmynd10', 'Zmynd11', 'Znhit1', 'Znrf1', 'Znrf2', 'Zranb2', 'Zswim6',
#        'Zyg11b', 'Zzef1', 'l7Rn6'],
#       dtype='object', name='index', length=4583)
# [2.38945001e-04 1.40535542e-04 1.00048198e-04 ... 1.89986187e-05
#  4.60372369e-05 4.07476015e-05]
# T cell
# training...
# result writing
# Index(['0610007C21Rik', '0610007L01Rik', '0610007N19Rik', '0610007P14Rik',
#        '0610007P22Rik', '0610009D07Rik', '0610010K14Rik', '0610010O12Rik',
#        '0610031J06Rik', '0610037P05Rik',
#        ...
#        'Zscan20', 'Zscan21', 'Zscan29', 'Zscan4c', 'Zscan4e', 'Zswim3',
#        'Zswim6', 'Zswim7', 'Zwint', 'Zyx'],
#       dtype='object', name='index', length=4583)
# [4.22016232e-05 1.00468522e-04 0.00000000e+00 ... 0.00000000e+00
#  0.00000000e+00 5.35394048e-05]
# kidney collecting duct principal cell
# training...
# result writing
# Index(['Clu', 'D630042F21Rik', 'Pgam2', 'Slc12a3'], dtype='object', name='index')
# [0.12050526 0.15336438 0.43903999 0.28709036]
# macrophage
# training...
# result writing
# Index(['0610007N19Rik', '0610007P08Rik', '0610007P14Rik', '0610007P22Rik',
#        '0610008F07Rik', '0610009B22Rik', '0610009D07Rik', '0610009L18Rik',
#        '0610009O20Rik', '0610010B08Rik',
#        ...
#        'Zmynd8', 'Znhit1', 'Znrf1', 'Znrf2', 'Zranb2', 'Zswim4', 'Zufsp',
#        'Zyg11b', 'Zyx', 'Zzef1'],
#       dtype='object', name='index', length=4583)
# [0.00000000e+00 0.00000000e+00 1.48352644e-05 ... 0.00000000e+00
#  1.84787222e-04 1.01543033e-05]
# epithelial cell of proximal tubule
# training...
# result writing
# Index(['0610005C13Rik', '0610007C21Rik', '0610007L01Rik', '0610007N19Rik',
#        '0610007P14Rik', '0610009B22Rik', '0610009D07Rik', '0610010K14Rik',
#        '0610010O12Rik', '0610011F06Rik',
#        ...
#        'Znfx1', 'Znhit1', 'Znhit6', 'Znrf1', 'Znrf2', 'Zswim1', 'Zyx', 'Zzef1',
#        'Zzz3', 'l7Rn6'],
#       dtype='object', name='index', length=4583)
# [7.64822937e-05 6.47397331e-05 6.79348830e-05 ... 2.73389689e-05
#  4.43559935e-05 1.00933156e-05]
#      Kidney-new-24m-cluster  Kidney-new-24m-cluster_gini  \
# 0                    Beta-s                     0.457965
# 1                   Gm16861                     0.173545
# 2                     Plin5                     0.102318
# 3                   Sec14l3                     0.266172
# 4                       NaN                          NaN
# 5                       NaN                          NaN
# 6                       NaN                          NaN
# 7                       NaN                          NaN
# 8                       NaN                          NaN
# 9                       NaN                          NaN
# 10                      NaN                          NaN
# 11                      NaN                          NaN
# 12                      NaN                          NaN
# 13                      NaN                          NaN
# 14                      NaN                          NaN
# 15                      NaN                          NaN
# 16                      NaN                          NaN
# 17                      NaN                          NaN
# 18                      NaN                          NaN
# 19                      NaN                          NaN
# 20                      NaN                          NaN
# 21                      NaN                          NaN
# 22                      NaN                          NaN
# 23                      NaN                          NaN
# 24                      NaN                          NaN
# 25                      NaN                          NaN
# 26                      NaN                          NaN
# 27                      NaN                          NaN
# 28                      NaN                          NaN
# 29                      NaN                          NaN
# ...                     ...                          ...
# 9132                    NaN                          NaN
# 9133                    NaN                          NaN
# 9134                    NaN                          NaN
# 9135                    NaN                          NaN
# 9136                    NaN                          NaN
# 9137                    NaN                          NaN
# 9138                    NaN                          NaN
# 9139                    NaN                          NaN
# 9140                    NaN                          NaN
# 9141                    NaN                          NaN
# 9142                    NaN                          NaN
# 9143                    NaN                          NaN
# 9144                    NaN                          NaN
# 9145                    NaN                          NaN
# 9146                    NaN                          NaN
# 9147                    NaN                          NaN
# 9148                    NaN                          NaN
# 9149                    NaN                          NaN
# 9150                    NaN                          NaN
# 9151                    NaN                          NaN
# 9152                    NaN                          NaN
# 9153                    NaN                          NaN
# 9154                    NaN                          NaN
# 9155                    NaN                          NaN
# 9156                    NaN                          NaN
# 9157                    NaN                          NaN
# 9158                    NaN                          NaN
# 9159                    NaN                          NaN
# 9160                    NaN                          NaN
# 9161                    NaN                          NaN
#
#      kidney loop of Henle ascending limb epithelial cell  \
# 0                                               Slc12a1
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...
# 9132                                                NaN
# 9133                                                NaN
# 9134                                                NaN
# 9135                                                NaN
# 9136                                                NaN
# 9137                                                NaN
# 9138                                                NaN
# 9139                                                NaN
# 9140                                                NaN
# 9141                                                NaN
# 9142                                                NaN
# 9143                                                NaN
# 9144                                                NaN
# 9145                                                NaN
# 9146                                                NaN
# 9147                                                NaN
# 9148                                                NaN
# 9149                                                NaN
# 9150                                                NaN
# 9151                                                NaN
# 9152                                                NaN
# 9153                                                NaN
# 9154                                                NaN
# 9155                                                NaN
# 9156                                                NaN
# 9157                                                NaN
# 9158                                                NaN
# 9159                                                NaN
# 9160                                                NaN
# 9161                                                NaN
#
#       kidney loop of Henle ascending limb epithelial cell_gini  \
# 0                                                   1.0
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...
# 9132                                                NaN
# 9133                                                NaN
# 9134                                                NaN
# 9135                                                NaN
# 9136                                                NaN
# 9137                                                NaN
# 9138                                                NaN
# 9139                                                NaN
# 9140                                                NaN
# 9141                                                NaN
# 9142                                                NaN
# 9143                                                NaN
# 9144                                                NaN
# 9145                                                NaN
# 9146                                                NaN
# 9147                                                NaN
# 9148                                                NaN
# 9149                                                NaN
# 9150                                                NaN
# 9151                                                NaN
# 9152                                                NaN
# 9153                                                NaN
# 9154                                                NaN
# 9155                                                NaN
# 9156                                                NaN
# 9157                                                NaN
# 9158                                                NaN
# 9159                                                NaN
# 9160                                                NaN
# 9161                                                NaN
#
#      fenestrated cell  fenestrated cell_gini     mesangial cell  \
# 0       0610007C21Rik               0.000000      0610007C21Rik
# 1       0610007L01Rik               0.000000      0610007L01Rik
# 2       0610007N19Rik               0.000059      0610007N19Rik
# 3       0610007P14Rik               0.000000      0610007P08Rik
# 4       0610009D07Rik               0.000000      0610007P14Rik
# 5       0610009O20Rik               0.000012      0610007P22Rik
# 6       0610010K14Rik               0.000018      0610008F07Rik
# 7       0610010O12Rik               0.000061      0610009B14Rik
# 8       0610011F06Rik               0.000117      0610009B22Rik
# 9       0610012G03Rik               0.000014      0610009D07Rik
# 10      0610031J06Rik               0.000005      0610009L18Rik
# 11      0610037L13Rik               0.000000      0610009O20Rik
# 12      0610039K10Rik               0.000000      0610010B08Rik
# 13      0610040J01Rik               0.000011      0610010F05Rik
# 14      0910001L09Rik               0.000023      0610010K14Rik
# 15          100043387               0.000095      0610010O12Rik
# 16      1100001G20Rik               0.000009      0610011F06Rik
# 17      1110001A16Rik               0.000087      0610011L14Rik
# 18      1110001J03Rik               0.000000      0610012G03Rik
# 19      1110004E09Rik               0.000015      0610012H03Rik
# 20      1110004F10Rik               0.000004      0610030E20Rik
# 21      1110006O24Rik               0.000000      0610031J06Rik
# 22      1110007C09Rik               0.000020      0610031O16Rik
# 23      1110008F13Rik               0.000000      0610037L13Rik
# 24      1110008P14Rik               0.000089      0610037P05Rik
# 25      1110012L19Rik               0.000000      0610038B21Rik
# 26      1110014N23Rik               0.000004      0610038L08Rik
# 27      1110017F19Rik               0.000004      0610039K10Rik
# 28      1110018J18Rik               0.000008      0610040B10Rik
# 29      1110034A24Rik               0.000000      0610040F04Rik
# ...               ...                    ...                ...
# 9132              NaN                    NaN             Zfp930
# 9133              NaN                    NaN             Zfp934
# 9134              NaN                    NaN             Zfp938
# 9135              NaN                    NaN             Zfp945
# 9136              NaN                    NaN             Zfp954
# 9137              NaN                    NaN              Zfpl1
# 9138              NaN                    NaN              Zfpm1
# 9139              NaN                    NaN              Zfpm2
# 9140              NaN                    NaN               Zhx3
# 9141              NaN                    NaN               Zik1
# 9142              NaN                    NaN            Zkscan3
# 9143              NaN                    NaN              Zmiz1
# 9144              NaN                    NaN              Zmym2
# 9145              NaN                    NaN            Zmynd11
# 9146              NaN                    NaN            Zmynd15
# 9147              NaN                    NaN            Zmynd19
# 9148              NaN                    NaN             Zmynd8
# 9149              NaN                    NaN            Znf512b
# 9150              NaN                    NaN          Znhit2-ps
# 9151              NaN                    NaN             Znhit6
# 9152              NaN                    NaN              Znrf1
# 9153              NaN                    NaN              Znrf3
# 9154              NaN                    NaN            Zscan22
# 9155              NaN                    NaN            Zscan29
# 9156              NaN                    NaN             Zwilch
# 9157              NaN                    NaN              Zwint
# 9158              NaN                    NaN               Zxdc
# 9159              NaN                    NaN                Zyx
# 9160              NaN                    NaN               Zzz3
# 9161              NaN                    NaN  zsGreen_transgene
#
#       mesangial cell_gini B cell  B cell_gini  \
# 0            2.071603e-05   Ccr7     0.189172
# 1            8.220964e-07  Cd79a     0.360559
# 2            0.000000e+00   Ly6d     0.368927
# 3            0.000000e+00  Ms4a1     0.081342
# 4            0.000000e+00    NaN          NaN
# 5            0.000000e+00    NaN          NaN
# 6            0.000000e+00    NaN          NaN
# 7            0.000000e+00    NaN          NaN
# 8            0.000000e+00    NaN          NaN
# 9            2.743943e-05    NaN          NaN
# 10           4.275988e-05    NaN          NaN
# 11           0.000000e+00    NaN          NaN
# 12           0.000000e+00    NaN          NaN
# 13           0.000000e+00    NaN          NaN
# 14           8.747161e-05    NaN          NaN
# 15           0.000000e+00    NaN          NaN
# 16           0.000000e+00    NaN          NaN
# 17           1.440891e-05    NaN          NaN
# 18           2.134694e-05    NaN          NaN
# 19           0.000000e+00    NaN          NaN
# 20           1.412055e-05    NaN          NaN
# 21           0.000000e+00    NaN          NaN
# 22           0.000000e+00    NaN          NaN
# 23           0.000000e+00    NaN          NaN
# 24           0.000000e+00    NaN          NaN
# 25           0.000000e+00    NaN          NaN
# 26           3.802342e-05    NaN          NaN
# 27           0.000000e+00    NaN          NaN
# 28           0.000000e+00    NaN          NaN
# 29           0.000000e+00    NaN          NaN
# ...                   ...    ...          ...
# 9132         0.000000e+00    NaN          NaN
# 9133         0.000000e+00    NaN          NaN
# 9134         0.000000e+00    NaN          NaN
# 9135         0.000000e+00    NaN          NaN
# 9136         1.509168e-05    NaN          NaN
# 9137         0.000000e+00    NaN          NaN
# 9138         0.000000e+00    NaN          NaN
# 9139         2.575568e-04    NaN          NaN
# 9140         0.000000e+00    NaN          NaN
# 9141         1.204972e-04    NaN          NaN
# 9142         0.000000e+00    NaN          NaN
# 9143         5.182341e-05    NaN          NaN
# 9144         0.000000e+00    NaN          NaN
# 9145         0.000000e+00    NaN          NaN
# 9146         0.000000e+00    NaN          NaN
# 9147         3.090281e-05    NaN          NaN
# 9148         0.000000e+00    NaN          NaN
# 9149         9.749315e-05    NaN          NaN
# 9150         0.000000e+00    NaN          NaN
# 9151         0.000000e+00    NaN          NaN
# 9152         0.000000e+00    NaN          NaN
# 9153         1.251808e-04    NaN          NaN
# 9154         0.000000e+00    NaN          NaN
# 9155         0.000000e+00    NaN          NaN
# 9156         0.000000e+00    NaN          NaN
# 9157         3.706723e-05    NaN          NaN
# 9158         2.356257e-04    NaN          NaN
# 9159         1.316026e-04    NaN          NaN
# 9160         0.000000e+00    NaN          NaN
# 9161         0.000000e+00    NaN          NaN
#
#      kidney collecting duct epithelial cell  \
# 0                             0610005C13Rik
# 1                             0610007C21Rik
# 2                             0610007N19Rik
# 3                             0610007P14Rik
# 4                             0610009D07Rik
# 5                             0610010K14Rik
# 6                             0610010O12Rik
# 7                             0610011F06Rik
# 8                             0610012G03Rik
# 9                             0610012H03Rik
# 10                            0610031J06Rik
# 11                            0610037L13Rik
# 12                            0610038B21Rik
# 13                            0610040J01Rik
# 14                            0910001L09Rik
# 15                            1110001J03Rik
# 16                            1110002B05Rik
# 17                            1110003E01Rik
# 18                            1110004E09Rik
# 19                            1110004F10Rik
# 20                            1110008P14Rik
# 21                            1110014N23Rik
# 22                            1110017F19Rik
# 23                            1110018J18Rik
# 24                            1110028C15Rik
# 25                            1110032A03Rik
# 26                            1110034G24Rik
# 27                            1110038D17Rik
# 28                            1110038F14Rik
# 29                            1110049F12Rik
# ...                                     ...
# 9132                                    NaN
# 9133                                    NaN
# 9134                                    NaN
# 9135                                    NaN
# 9136                                    NaN
# 9137                                    NaN
# 9138                                    NaN
# 9139                                    NaN
# 9140                                    NaN
# 9141                                    NaN
# 9142                                    NaN
# 9143                                    NaN
# 9144                                    NaN
# 9145                                    NaN
# 9146                                    NaN
# 9147                                    NaN
# 9148                                    NaN
# 9149                                    NaN
# 9150                                    NaN
# 9151                                    NaN
# 9152                                    NaN
# 9153                                    NaN
# 9154                                    NaN
# 9155                                    NaN
# 9156                                    NaN
# 9157                                    NaN
# 9158                                    NaN
# 9159                                    NaN
# 9160                                    NaN
# 9161                                    NaN
#
#       kidney collecting duct epithelial cell_gini         T cell  T cell_gini  \
# 0                                        0.000239  0610007C21Rik     0.000042
# 1                                        0.000141  0610007L01Rik     0.000100
# 2                                        0.000100  0610007N19Rik     0.000000
# 3                                        0.000009  0610007P14Rik     0.000054
# 4                                        0.000067  0610007P22Rik     0.000050
# 5                                        0.000058  0610009D07Rik     0.000049
# 6                                        0.000241  0610010K14Rik     0.000012
# 7                                        0.000118  0610010O12Rik     0.000026
# 8                                        0.000125  0610031J06Rik     0.000095
# 9                                        0.000171  0610037P05Rik     0.000141
# 10                                       0.000161  0610040B10Rik     0.000000
# 11                                       0.000039  0910001L09Rik     0.000000
# 12                                       0.000053  1110001A16Rik     0.000018
# 13                                       0.000005  1110001J03Rik     0.000075
# 14                                       0.000218  1110002B05Rik     0.000017
# 15                                       0.000081  1110002L01Rik     0.000055
# 16                                       0.000049  1110003E01Rik     0.000016
# 17                                       0.000081  1110004E09Rik     0.000000
# 18                                       0.000111  1110007C09Rik     0.000000
# 19                                       0.000007  1110008F13Rik     0.000048
# 20                                       0.000056  1110008P14Rik     0.000109
# 21                                       0.000010  1110014N23Rik     0.000018
# 22                                       0.000073  1110032A03Rik     0.000011
# 23                                       0.000010  1110034A24Rik     0.000000
# 24                                       0.000065  1110034B05Rik     0.000000
# 25                                       0.000059  1110037F02Rik     0.000000
# 26                                       0.000046  1110038F14Rik     0.000020
# 27                                       0.000093  1110054O05Rik     0.000000
# 28                                       0.000018  1110065P20Rik     0.000000
# 29                                       0.000030  1190002F15Rik     0.000042
# ...                                           ...            ...          ...
# 9132                                          NaN            NaN          NaN
# 9133                                          NaN            NaN          NaN
# 9134                                          NaN            NaN          NaN
# 9135                                          NaN            NaN          NaN
# 9136                                          NaN            NaN          NaN
# 9137                                          NaN            NaN          NaN
# 9138                                          NaN            NaN          NaN
# 9139                                          NaN            NaN          NaN
# 9140                                          NaN            NaN          NaN
# 9141                                          NaN            NaN          NaN
# 9142                                          NaN            NaN          NaN
# 9143                                          NaN            NaN          NaN
# 9144                                          NaN            NaN          NaN
# 9145                                          NaN            NaN          NaN
# 9146                                          NaN            NaN          NaN
# 9147                                          NaN            NaN          NaN
# 9148                                          NaN            NaN          NaN
# 9149                                          NaN            NaN          NaN
# 9150                                          NaN            NaN          NaN
# 9151                                          NaN            NaN          NaN
# 9152                                          NaN            NaN          NaN
# 9153                                          NaN            NaN          NaN
# 9154                                          NaN            NaN          NaN
# 9155                                          NaN            NaN          NaN
# 9156                                          NaN            NaN          NaN
# 9157                                          NaN            NaN          NaN
# 9158                                          NaN            NaN          NaN
# 9159                                          NaN            NaN          NaN
# 9160                                          NaN            NaN          NaN
# 9161                                          NaN            NaN          NaN
#
#      kidney collecting duct principal cell  \
# 0                                      Clu
# 1                            D630042F21Rik
# 2                                    Pgam2
# 3                                  Slc12a3
# 4                                      NaN
# 5                                      NaN
# 6                                      NaN
# 7                                      NaN
# 8                                      NaN
# 9                                      NaN
# 10                                     NaN
# 11                                     NaN
# 12                                     NaN
# 13                                     NaN
# 14                                     NaN
# 15                                     NaN
# 16                                     NaN
# 17                                     NaN
# 18                                     NaN
# 19                                     NaN
# 20                                     NaN
# 21                                     NaN
# 22                                     NaN
# 23                                     NaN
# 24                                     NaN
# 25                                     NaN
# 26                                     NaN
# 27                                     NaN
# 28                                     NaN
# 29                                     NaN
# ...                                    ...
# 9132                                   NaN
# 9133                                   NaN
# 9134                                   NaN
# 9135                                   NaN
# 9136                                   NaN
# 9137                                   NaN
# 9138                                   NaN
# 9139                                   NaN
# 9140                                   NaN
# 9141                                   NaN
# 9142                                   NaN
# 9143                                   NaN
# 9144                                   NaN
# 9145                                   NaN
# 9146                                   NaN
# 9147                                   NaN
# 9148                                   NaN
# 9149                                   NaN
# 9150                                   NaN
# 9151                                   NaN
# 9152                                   NaN
# 9153                                   NaN
# 9154                                   NaN
# 9155                                   NaN
# 9156                                   NaN
# 9157                                   NaN
# 9158                                   NaN
# 9159                                   NaN
# 9160                                   NaN
# 9161                                   NaN
#
#       kidney collecting duct principal cell_gini     macrophage  \
# 0                                       0.120505  0610007N19Rik
# 1                                       0.153364  0610007P08Rik
# 2                                       0.439040  0610007P14Rik
# 3                                       0.287090  0610007P22Rik
# 4                                            NaN  0610008F07Rik
# 5                                            NaN  0610009B22Rik
# 6                                            NaN  0610009D07Rik
# 7                                            NaN  0610009L18Rik
# 8                                            NaN  0610009O20Rik
# 9                                            NaN  0610010B08Rik
# 10                                           NaN  0610010F05Rik
# 11                                           NaN  0610010K14Rik
# 12                                           NaN  0610010O12Rik
# 13                                           NaN  0610011F06Rik
# 14                                           NaN  0610011L14Rik
# 15                                           NaN  0610012G03Rik
# 16                                           NaN  0610012H03Rik
# 17                                           NaN  0610030E20Rik
# 18                                           NaN  0610031J06Rik
# 19                                           NaN  0610037P05Rik
# 20                                           NaN  0610038B21Rik
# 21                                           NaN  0610038L08Rik
# 22                                           NaN  0610039K10Rik
# 23                                           NaN  0610040B10Rik
# 24                                           NaN  0610040F04Rik
# 25                                           NaN  0610043K17Rik
# 26                                           NaN  0910001L09Rik
# 27                                           NaN      100043387
# 28                                           NaN  1100001G20Rik
# 29                                           NaN  1110001J03Rik
# ...                                          ...            ...
# 9132                                         NaN            NaN
# 9133                                         NaN            NaN
# 9134                                         NaN            NaN
# 9135                                         NaN            NaN
# 9136                                         NaN            NaN
# 9137                                         NaN            NaN
# 9138                                         NaN            NaN
# 9139                                         NaN            NaN
# 9140                                         NaN            NaN
# 9141                                         NaN            NaN
# 9142                                         NaN            NaN
# 9143                                         NaN            NaN
# 9144                                         NaN            NaN
# 9145                                         NaN            NaN
# 9146                                         NaN            NaN
# 9147                                         NaN            NaN
# 9148                                         NaN            NaN
# 9149                                         NaN            NaN
# 9150                                         NaN            NaN
# 9151                                         NaN            NaN
# 9152                                         NaN            NaN
# 9153                                         NaN            NaN
# 9154                                         NaN            NaN
# 9155                                         NaN            NaN
# 9156                                         NaN            NaN
# 9157                                         NaN            NaN
# 9158                                         NaN            NaN
# 9159                                         NaN            NaN
# 9160                                         NaN            NaN
# 9161                                         NaN            NaN
#
#       macrophage_gini epithelial cell of proximal tubule  \
# 0            0.000000                      0610005C13Rik
# 1            0.000000                      0610007C21Rik
# 2            0.000015                      0610007L01Rik
# 3            0.000000                      0610007N19Rik
# 4            0.000000                      0610007P14Rik
# 5            0.000013                      0610009B22Rik
# 6            0.000014                      0610009D07Rik
# 7            0.000000                      0610010K14Rik
# 8            0.000000                      0610010O12Rik
# 9            0.000000                      0610011F06Rik
# 10           0.000010                      0610012G03Rik
# 11           0.000009                      0610012H03Rik
# 12           0.000007                      0610031J06Rik
# 13           0.000000                      0610031O16Rik
# 14           0.000000                      0610037P05Rik
# 15           0.000018                      0910001L09Rik
# 16           0.000000                      1110001A16Rik
# 17           0.000000                      1110001J03Rik
# 18           0.000018                      1110002B05Rik
# 19           0.000000                      1110003E01Rik
# 20           0.000000                      1110004E09Rik
# 21           0.000000                      1110004F10Rik
# 22           0.000000                      1110007C09Rik
# 23           0.000000                      1110008F13Rik
# 24           0.000000                      1110008P14Rik
# 25           0.000000                      1110017F19Rik
# 26           0.000000                      1110019D14Rik
# 27           0.000017                      1110020G09Rik
# 28           0.000011                      1110028C15Rik
# 29           0.000000                      1110032A03Rik
# ...               ...                                ...
# 9132              NaN                                NaN
# 9133              NaN                                NaN
# 9134              NaN                                NaN
# 9135              NaN                                NaN
# 9136              NaN                                NaN
# 9137              NaN                                NaN
# 9138              NaN                                NaN
# 9139              NaN                                NaN
# 9140              NaN                                NaN
# 9141              NaN                                NaN
# 9142              NaN                                NaN
# 9143              NaN                                NaN
# 9144              NaN                                NaN
# 9145              NaN                                NaN
# 9146              NaN                                NaN
# 9147              NaN                                NaN
# 9148              NaN                                NaN
# 9149              NaN                                NaN
# 9150              NaN                                NaN
# 9151              NaN                                NaN
# 9152              NaN                                NaN
# 9153              NaN                                NaN
# 9154              NaN                                NaN
# 9155              NaN                                NaN
# 9156              NaN                                NaN
# 9157              NaN                                NaN
# 9158              NaN                                NaN
# 9159              NaN                                NaN
# 9160              NaN                                NaN
# 9161              NaN                                NaN
#
#       epithelial cell of proximal tubule_gini
# 0                                    0.000076
# 1                                    0.000065
# 2                                    0.000068
# 3                                    0.000084
# 4                                    0.000011
# 5                                    0.000019
# 6                                    0.000085
# 7                                    0.000106
# 8                                    0.000095
# 9                                    0.000435
# 10                                   0.000116
# 11                                   0.000904
# 12                                   0.000038
# 13                                   0.000003
# 14                                   0.000137
# 15                                   0.000173
# 16                                   0.000020
# 17                                   0.000181
# 18                                   0.000112
# 19                                   0.000084
# 20                                   0.000024
# 21                                   0.000067
# 22                                   0.000100
# 23                                   0.000095
# 24                                   0.000058
# 25                                   0.000084
# 26                                   0.000116
# 27                                   0.000016
# 28                                   0.000019
# 29                                   0.000086
# ...                                       ...
# 9132                                      NaN
# 9133                                      NaN
# 9134                                      NaN
# 9135                                      NaN
# 9136                                      NaN
# 9137                                      NaN
# 9138                                      NaN
# 9139                                      NaN
# 9140                                      NaN
# 9141                                      NaN
# 9142                                      NaN
# 9143                                      NaN
# 9144                                      NaN
# 9145                                      NaN
# 9146                                      NaN
# 9147                                      NaN
# 9148                                      NaN
# 9149                                      NaN
# 9150                                      NaN
# 9151                                      NaN
# 9152                                      NaN
# 9153                                      NaN
# 9154                                      NaN
# 9155                                      NaN
# 9156                                      NaN
# 9157                                      NaN
# 9158                                      NaN
# 9159                                      NaN
# 9160                                      NaN
# 9161                                      NaN
#
# [9162 rows x 20 columns]

# %%
results_celltype_cv.to_csv('KidneyFacsCellType1000.csv')

# %% [markdown]
# # Now do the same for kidney age

# %%
adata = read_h5ad('/Users/madelinepark/Downloads/Kidney_facs.h5ad')
tiss = adata

# %%
results_age_cv = pd.DataFrame() #create results data frame 

for c in list(set(tiss.obs['age'])): 
    print(c)
    age_of_interest = c
    tiss.obs['age_type_of_interest'] = 'rest' #moved into, was outside before
    tiss.obs.loc[tiss.obs['age'] == age_of_interest,'age_type_of_interest'] = age_of_interest

    clf = RandomForestClassifier(n_estimators=10, random_state=0, n_jobs=-1, oob_score=True)
    selector = RFECV(clf, step=0.2, cv=3, n_jobs=4) # step = % rounded down at each iteration  
    
# #     tiss.obs.loc[tiss.obs[tiss.obs['age'] == age_of_interest].index,'age_type_of_interest'] = age_of_interest
#     tiss.obs.loc[tiss.obs['age'] == age_of_interest,'age_type_of_interest'] = age_of_interest

    feat_labels = tiss.var_names 
    X = tiss.X
    y = tiss.obs['age_type_of_interest']
    
    print('training...')
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05, random_state=0) 
    clf.fit(X_train, y_train)
    selector.fit(X_train, y_train)
    feature_selected = feat_labels[selector.support_] 
    
    print('result writing')
    column_headings = []
    column_headings.append(c)
    column_headings.append(c + '_gini')
    
    resaux = pd.DataFrame(columns=column_headings)
    resaux[c] = feature_selected
    resaux[c + '_gini'] = (selector.estimator_.feature_importances_)
    
    print(feature_selected)
    print (selector.estimator_.feature_importances_)
    
    results_age_cv = pd.concat([results_age_cv,resaux],axis=1)
    
    #adding this smart cheeky line
    print(list(set(tiss.obs['age_type_of_interest'])))
    
    tiss.obs['age_type_of_interest'] = 'rest'
    
results_age_cv
# Out:
# 24m
# training...
# /Users/madelinepark/anaconda3/envs/scanpytest/lib/python3.6/site-packages/sklearn/ensemble/forest.py:460: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /Users/madelinepark/anaconda3/envs/scanpytest/lib/python3.6/site-packages/sklearn/ensemble/forest.py:465: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /Users/madelinepark/anaconda3/envs/scanpytest/lib/python3.6/site-packages/sklearn/ensemble/forest.py:460: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /Users/madelinepark/anaconda3/envs/scanpytest/lib/python3.6/site-packages/sklearn/ensemble/forest.py:465: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /Users/madelinepark/anaconda3/envs/scanpytest/lib/python3.6/site-packages/sklearn/ensemble/forest.py:460: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /Users/madelinepark/anaconda3/envs/scanpytest/lib/python3.6/site-packages/sklearn/ensemble/forest.py:465: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /Users/madelinepark/anaconda3/envs/scanpytest/lib/python3.6/site-packages/sklearn/ensemble/forest.py:460: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /Users/madelinepark/anaconda3/envs/scanpytest/lib/python3.6/site-packages/sklearn/ensemble/forest.py:465: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# result writing
# Index(['0610007C21Rik', '0610007L01Rik', '0610007N19Rik', '0610007P08Rik',
#        '0610007P14Rik', '0610007P22Rik', '0610008F07Rik', '0610009B14Rik',
#        '0610009B22Rik', '0610009D07Rik',
#        ...
#        'Zxda', 'Zxdb', 'Zxdc', 'Zyg11a', 'Zyg11b', 'Zyx', 'Zzef1', 'Zzz3', 'a',
#        'zsGreen_transgene'],
#       dtype='object', name='index', length=18320)
# [0. 0. 0. ... 0. 0. 0.]
# ['rest', '24m']
# 3m
# training...
# /Users/madelinepark/anaconda3/envs/scanpytest/lib/python3.6/site-packages/sklearn/ensemble/forest.py:460: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /Users/madelinepark/anaconda3/envs/scanpytest/lib/python3.6/site-packages/sklearn/ensemble/forest.py:465: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /Users/madelinepark/anaconda3/envs/scanpytest/lib/python3.6/site-packages/sklearn/ensemble/forest.py:460: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /Users/madelinepark/anaconda3/envs/scanpytest/lib/python3.6/site-packages/sklearn/ensemble/forest.py:465: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /Users/madelinepark/anaconda3/envs/scanpytest/lib/python3.6/site-packages/sklearn/ensemble/forest.py:460: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /Users/madelinepark/anaconda3/envs/scanpytest/lib/python3.6/site-packages/sklearn/ensemble/forest.py:465: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /Users/madelinepark/anaconda3/envs/scanpytest/lib/python3.6/site-packages/sklearn/ensemble/forest.py:460: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /Users/madelinepark/anaconda3/envs/scanpytest/lib/python3.6/site-packages/sklearn/ensemble/forest.py:465: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /Users/madelinepark/anaconda3/envs/scanpytest/lib/python3.6/site-packages/sklearn/ensemble/forest.py:460: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /Users/madelinepark/anaconda3/envs/scanpytest/lib/python3.6/site-packages/sklearn/ensemble/forest.py:465: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /Users/madelinepark/anaconda3/envs/scanpytest/lib/python3.6/site-packages/sklearn/ensemble/forest.py:460: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /Users/madelinepark/anaconda3/envs/scanpytest/lib/python3.6/site-packages/sklearn/ensemble/forest.py:465: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /Users/madelinepark/anaconda3/envs/scanpytest/lib/python3.6/site-packages/sklearn/ensemble/forest.py:460: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /Users/madelinepark/anaconda3/envs/scanpytest/lib/python3.6/site-packages/sklearn/ensemble/forest.py:465: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# result writing
# Index(['0610007P08Rik', '0610007P14Rik', '0610007P22Rik', '0610008F07Rik',
#        '0610009B14Rik', '0610009B22Rik', '0610009D07Rik', '0610009L18Rik',
#        '0610009O20Rik', '0610010B08Rik',
#        ...
#        'Zfp157', 'Zfp161', 'Zfp185', 'Zfp187', 'Zfp212', 'Zfp281', 'Zfp422',
#        'Zfpl1', 'Zg16', 'zsGreen_transgene'],
#       dtype='object', name='index', length=4583)
# [0. 0. 0. ... 0. 0. 0.]
# ['rest', '3m']
#                      24m  24m_gini             3m   3m_gini
# 0          0610007C21Rik  0.000000  0610007P08Rik  0.000000
# 1          0610007L01Rik  0.000000  0610007P14Rik  0.000000
# 2          0610007N19Rik  0.000000  0610007P22Rik  0.000000
# 3          0610007P08Rik  0.000000  0610008F07Rik  0.000000
# 4          0610007P14Rik  0.000000  0610009B14Rik  0.000000
# 5          0610007P22Rik  0.000000  0610009B22Rik  0.000000
# 6          0610008F07Rik  0.000000  0610009D07Rik  0.000000
# 7          0610009B14Rik  0.000000  0610009L18Rik  0.000289
# 8          0610009B22Rik  0.000292  0610009O20Rik  0.000000
# 9          0610009D07Rik  0.000000  0610010B08Rik  0.000000
# 10         0610009L18Rik  0.000879  0610010F05Rik  0.000000
# 11         0610009O20Rik  0.000000  0610010K14Rik  0.000000
# 12         0610010B08Rik  0.000000  0610010O12Rik  0.000000
# 13         0610010F05Rik  0.000000  0610011F06Rik  0.000877
# 14         0610010K14Rik  0.000000  0610011L14Rik  0.000000
# 15         0610010O12Rik  0.000000  0610012G03Rik  0.000000
# 16         0610011F06Rik  0.001180  0610012H03Rik  0.000000
# 17         0610011L14Rik  0.000000  0610030E20Rik  0.000826
# 18         0610012G03Rik  0.000000  0610031J06Rik  0.000578
# 19         0610012H03Rik  0.000000  0610031O16Rik  0.000000
# 20         0610030E20Rik  0.000000  0610037L13Rik  0.000000
# 21         0610031J06Rik  0.000000  0610037P05Rik  0.000000
# 22         0610031O16Rik  0.000000  0610038B21Rik  0.000000
# 23         0610037L13Rik  0.000000  0610038L08Rik  0.000000
# 24         0610037P05Rik  0.000000  0610039K10Rik  0.000000
# 25         0610038B21Rik  0.000000  0610040B10Rik  0.000000
# 26         0610038L08Rik  0.000000  0610040F04Rik  0.000000
# 27         0610039K10Rik  0.000000  0610040J01Rik  0.000000
# 28         0610040B10Rik  0.000000  0610043K17Rik  0.000000
# 29         0610040F04Rik  0.000000  0910001L09Rik  0.000000
# ...                  ...       ...            ...       ...
# 18290            Zscan22  0.000000            NaN       NaN
# 18291            Zscan29  0.000000            NaN       NaN
# 18292            Zscan4a  0.000000            NaN       NaN
# 18293            Zscan4b  0.000000            NaN       NaN
# 18294            Zscan4c  0.000000            NaN       NaN
# 18295            Zscan4d  0.000000            NaN       NaN
# 18296            Zscan4e  0.000000            NaN       NaN
# 18297            Zscan4f  0.000000            NaN       NaN
# 18298            Zscan5b  0.000000            NaN       NaN
# 18299             Zswim1  0.000000            NaN       NaN
# 18300             Zswim2  0.000000            NaN       NaN
# 18301             Zswim3  0.000000            NaN       NaN
# 18302             Zswim4  0.000000            NaN       NaN
# 18303             Zswim5  0.000000            NaN       NaN
# 18304             Zswim6  0.000000            NaN       NaN
# 18305             Zswim7  0.000000            NaN       NaN
# 18306              Zufsp  0.000000            NaN       NaN
# 18307               Zw10  0.000000            NaN       NaN
# 18308             Zwilch  0.000000            NaN       NaN
# 18309              Zwint  0.000000            NaN       NaN
# 18310               Zxda  0.000000            NaN       NaN
# 18311               Zxdb  0.000000            NaN       NaN
# 18312               Zxdc  0.000000            NaN       NaN
# 18313             Zyg11a  0.000000            NaN       NaN
# 18314             Zyg11b  0.000000            NaN       NaN
# 18315                Zyx  0.001992            NaN       NaN
# 18316              Zzef1  0.000000            NaN       NaN
# 18317               Zzz3  0.000000            NaN       NaN
# 18318                  a  0.000000            NaN       NaN
# 18319  zsGreen_transgene  0.000000            NaN       NaN
#
# [18320 rows x 4 columns]

# %%
results_age_cv.to_csv('KidneyFacsAge1000TissReset.csv')

# %%
tiss.obs
# Out:
#                               FACS.selection  age batch  \
# index
# A11_B001261_S287_L003.mus-2-0         Viable  24m     0
# A12_B001261_S288_L003.mus-2-0         Viable  24m     0
# A15_B001261_S291_L003.mus-2-0         Viable  24m     0
# A16_B001261_S292_L003.mus-2-0         Viable  24m     0
# A17_B001261_S293_L003.mus-2-0         Viable  24m     0
# A18_B001261_S294_L003.mus-2-0         Viable  24m     0
# A20_B001261_S296_L003.mus-2-0         Viable  24m     0
# A21_B001261_S297_L003.mus-2-0         Viable  24m     0
# A3_B001261_S279_L003.mus-2-0          Viable  24m     0
# A4_B001261_S280_L003.mus-2-0          Viable  24m     0
# A6_B001261_S282_L003.mus-2-0          Viable  24m     0
# A7_B001261_S283_L003.mus-2-0          Viable  24m     0
# A9_B001261_S285_L003.mus-2-0          Viable  24m     0
# B18_B001261_S18_L003.mus-2-0                  rest
# B20_B001261_S20_L003.mus-2-0                  rest
# B22_B001261_S22_L003.mus-2-0                  rest
# B2_B001261_S2_L003.mus-2-0                    rest
# B6_B001261_S6_L003.mus-2-0                    rest
# B7_B001261_S7_L003.mus-2-0                    rest
# B8_B001261_S8_L003.mus-2-0                    rest
# C11_B001261_S35_L003.mus-2-0                  rest
# C13_B001261_S37_L003.mus-2-0                  rest
# C16_B001261_S40_L003.mus-2-0                  rest
# C17_B001261_S41_L003.mus-2-0                  rest
# C18_B001261_S42_L003.mus-2-0                  rest
# ...                                            ...
# P12.MAA000922.3_9_M.1.1-1                     rest
# P13.MAA000545.3_8_M.1.1-1                     rest
# P13.MAA000752.3_10_M.1.1-1                    rest
# P14.MAA000801.3_11_M.1.1-1                    rest
# P15.MAA000752.3_10_M.1.1-1                    rest
# P16.MAA000752.3_10_M.1.1-1                    rest
# P16.MAA000801.3_11_M.1.1-1                    rest
# P18.MAA000545.3_8_M.1.1-1                     rest
# P18.MAA000752.3_10_M.1.1-1                    rest
# P18.MAA000922.3_9_M.1.1-1                     rest
# P19.B002775.3_39_F.1.1-1                      rest
# P19.MAA000801.3_11_M.1.1-1                    rest
# P2.B001717.3_38_F.1.1-1                       rest
# P20.B001717.3_38_F.1.1-1                      rest
# P20.B002775.3_39_F.1.1-1                      rest
# P20.MAA000922.3_9_M.1.1-1                     rest
# P21.B002775.3_39_F.1.1-1                      rest
# P21.MAA000545.3_8_M.1.1-1                     rest
# P22.B001717.3_38_F.1.1-1                      rest
# P22.B002775.3_39_F.1.1-1                      rest
# P3.B002775.3_39_F.1.1-1                       rest
# P3.MAA000752.3_10_M.1.1-1                     rest
# P3.MAA000801.3_11_M.1.1-1                     rest
# P4.B001717.3_38_F.1.1-1                       rest
# P4.MAA000545.3_8_M.1.1-1                      rest
# P4.MAA000801.3_11_M.1.1-1                     rest
# P5.MAA000545.3_8_M.1.1-1                      rest
# P6.MAA000801.3_11_M.1.1-1                     rest
# P8.MAA000752.3_10_M.1.1-1                     rest
# P9.B001717.3_38_F.1.1-1                       rest
#
# [1400 rows x 20 columns]

# %%
results_cell_cv.to_csv('test3.csv')

# %% [markdown]
# # Kidney Facs 1000 trees same code as mammary split for cell type

# %%
adata = read_h5ad('/Users/madelinepark/Downloads/Kidney_facs.h5ad')
tiss = adata

# %%
results_celltype_cv = pd.DataFrame() #create results data frame 

for c in list(set(tiss.obs['cell_ontology_class'])): 
    print(c)
    cell_of_interest = c
    tiss.obs['cell_type_of_interest'] = 'rest' #moved into, was outside before
    tiss.obs.loc[tiss.obs['cell_ontology_class'] == cell_of_interest,'cell_type_of_interest'] = cell_of_interest

    clf = RandomForestClassifier(n_estimators=1000, random_state=0, n_jobs=-1, oob_score=True)
    selector = RFECV(clf, step=0.2, cv=3, n_jobs=4) # step = % rounded down at each iteration  
    
# #     tiss.obs.loc[tiss.obs[tiss.obs['age'] == age_of_interest].index,'age_type_of_interest'] = age_of_interest
#     tiss.obs.loc[tiss.obs['age'] == age_of_interest,'age_type_of_interest'] = age_of_interest

    feat_labels = tiss.var_names 
    X = tiss.X
    y = tiss.obs['cell_type_of_interest']
    
    print('training...')
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05, random_state=0) 
    clf.fit(X_train, y_train)
    selector.fit(X_train, y_train)
    feature_selected = feat_labels[selector.support_] 
    
    print('result writing')
    column_headings = []
    column_headings.append(c)
    column_headings.append(c + '_gini')
    
    resaux = pd.DataFrame(columns=column_headings)
    resaux[c] = feature_selected
    resaux[c + '_gini'] = (selector.estimator_.feature_importances_)
    
    print(feature_selected)
    print (selector.estimator_.feature_importances_)
    
    results_celltype_cv = pd.concat([results_celltype_cv,resaux],axis=1)
    
    tiss.obs['cell_type_of_interest'] = 'rest'
    
results_celltype_cv
# Out:
# Kidney-new-24m-cluster
# training...
# result writing
# Index(['Beta-s', 'Gm16861', 'Plin5', 'Sec14l3'], dtype='object', name='index')
# [0.45796539 0.173545   0.10231781 0.26617181]
# kidney loop of Henle ascending limb epithelial cell
# training...
# result writing
# Index(['Slc12a1'], dtype='object', name='index')
# [1.]
# fenestrated cell
# training...
# result writing
# Index(['0610007C21Rik', '0610007L01Rik', '0610007N19Rik', '0610007P14Rik',
#        '0610009D07Rik', '0610009O20Rik', '0610010K14Rik', '0610010O12Rik',
#        '0610011F06Rik', '0610012G03Rik',
#        ...
#        'Znfx1', 'Znhit1', 'Znhit6', 'Znrd1', 'Znrf1', 'Zpbp', 'Zranb1',
#        'Zswim6', 'Zw10', 'Zxdc'],
#       dtype='object', name='index', length=4583)
# [0.00000000e+00 0.00000000e+00 5.86593394e-05 ... 2.91909742e-05
#  0.00000000e+00 6.30596768e-05]
# mesangial cell
# training...
# result writing
# Index(['0610007C21Rik', '0610007L01Rik', '0610007N19Rik', '0610007P08Rik',
#        '0610007P14Rik', '0610007P22Rik', '0610008F07Rik', '0610009B14Rik',
#        '0610009B22Rik', '0610009D07Rik',
#        ...
#        'Znrf1', 'Znrf3', 'Zscan22', 'Zscan29', 'Zwilch', 'Zwint', 'Zxdc',
#        'Zyx', 'Zzz3', 'zsGreen_transgene'],
#       dtype='object', name='index', length=9162)
# [2.07160269e-05 8.22096357e-07 0.00000000e+00 ... 1.31602577e-04
#  0.00000000e+00 0.00000000e+00]
# B cell
# training...
# result writing
# Index(['Ccr7', 'Cd79a', 'Ly6d', 'Ms4a1'], dtype='object', name='index')
# [0.18917166 0.36055857 0.36892729 0.08134248]
# kidney collecting duct epithelial cell
# training...
# result writing
# Index(['0610005C13Rik', '0610007C21Rik', '0610007N19Rik', '0610007P14Rik',
#        '0610009D07Rik', '0610010K14Rik', '0610010O12Rik', '0610011F06Rik',
#        '0610012G03Rik', '0610012H03Rik',
#        ...
#        'Zmynd10', 'Zmynd11', 'Znhit1', 'Znrf1', 'Znrf2', 'Zranb2', 'Zswim6',
#        'Zyg11b', 'Zzef1', 'l7Rn6'],
#       dtype='object', name='index', length=4583)
# [2.38945001e-04 1.40535542e-04 1.00048198e-04 ... 1.89986187e-05
#  4.60372369e-05 4.07476015e-05]
# T cell
# training...
# result writing
# Index(['0610007C21Rik', '0610007L01Rik', '0610007N19Rik', '0610007P14Rik',
#        '0610007P22Rik', '0610009D07Rik', '0610010K14Rik', '0610010O12Rik',
#        '0610031J06Rik', '0610037P05Rik',
#        ...
#        'Zscan20', 'Zscan21', 'Zscan29', 'Zscan4c', 'Zscan4e', 'Zswim3',
#        'Zswim6', 'Zswim7', 'Zwint', 'Zyx'],
#       dtype='object', name='index', length=4583)
# [4.22016232e-05 1.00468522e-04 0.00000000e+00 ... 0.00000000e+00
#  0.00000000e+00 5.35394048e-05]
# kidney collecting duct principal cell
# training...
# result writing
# Index(['Clu', 'D630042F21Rik', 'Pgam2', 'Slc12a3'], dtype='object', name='index')
# [0.12050526 0.15336438 0.43903999 0.28709036]
# macrophage
# training...
# result writing
# Index(['0610007N19Rik', '0610007P08Rik', '0610007P14Rik', '0610007P22Rik',
#        '0610008F07Rik', '0610009B22Rik', '0610009D07Rik', '0610009L18Rik',
#        '0610009O20Rik', '0610010B08Rik',
#        ...
#        'Zmynd8', 'Znhit1', 'Znrf1', 'Znrf2', 'Zranb2', 'Zswim4', 'Zufsp',
#        'Zyg11b', 'Zyx', 'Zzef1'],
#       dtype='object', name='index', length=4583)
# [0.00000000e+00 0.00000000e+00 1.48352644e-05 ... 0.00000000e+00
#  1.84787222e-04 1.01543033e-05]
# epithelial cell of proximal tubule
# training...
# result writing
# Index(['0610005C13Rik', '0610007C21Rik', '0610007L01Rik', '0610007N19Rik',
#        '0610007P14Rik', '0610009B22Rik', '0610009D07Rik', '0610010K14Rik',
#        '0610010O12Rik', '0610011F06Rik',
#        ...
#        'Znfx1', 'Znhit1', 'Znhit6', 'Znrf1', 'Znrf2', 'Zswim1', 'Zyx', 'Zzef1',
#        'Zzz3', 'l7Rn6'],
#       dtype='object', name='index', length=4583)
# [7.64822937e-05 6.47397331e-05 6.79348830e-05 ... 2.73389689e-05
#  4.43559935e-05 1.00933156e-05]
#      Kidney-new-24m-cluster  Kidney-new-24m-cluster_gini  \
# 0                    Beta-s                     0.457965
# 1                   Gm16861                     0.173545
# 2                     Plin5                     0.102318
# 3                   Sec14l3                     0.266172
# 4                       NaN                          NaN
# 5                       NaN                          NaN
# 6                       NaN                          NaN
# 7                       NaN                          NaN
# 8                       NaN                          NaN
# 9                       NaN                          NaN
# 10                      NaN                          NaN
# 11                      NaN                          NaN
# 12                      NaN                          NaN
# 13                      NaN                          NaN
# 14                      NaN                          NaN
# 15                      NaN                          NaN
# 16                      NaN                          NaN
# 17                      NaN                          NaN
# 18                      NaN                          NaN
# 19                      NaN                          NaN
# 20                      NaN                          NaN
# 21                      NaN                          NaN
# 22                      NaN                          NaN
# 23                      NaN                          NaN
# 24                      NaN                          NaN
# 25                      NaN                          NaN
# 26                      NaN                          NaN
# 27                      NaN                          NaN
# 28                      NaN                          NaN
# 29                      NaN                          NaN
# ...                     ...                          ...
# 9132                    NaN                          NaN
# 9133                    NaN                          NaN
# 9134                    NaN                          NaN
# 9135                    NaN                          NaN
# 9136                    NaN                          NaN
# 9137                    NaN                          NaN
# 9138                    NaN                          NaN
# 9139                    NaN                          NaN
# 9140                    NaN                          NaN
# 9141                    NaN                          NaN
# 9142                    NaN                          NaN
# 9143                    NaN                          NaN
# 9144                    NaN                          NaN
# 9145                    NaN                          NaN
# 9146                    NaN                          NaN
# 9147                    NaN                          NaN
# 9148                    NaN                          NaN
# 9149                    NaN                          NaN
# 9150                    NaN                          NaN
# 9151                    NaN                          NaN
# 9152                    NaN                          NaN
# 9153                    NaN                          NaN
# 9154                    NaN                          NaN
# 9155                    NaN                          NaN
# 9156                    NaN                          NaN
# 9157                    NaN                          NaN
# 9158                    NaN                          NaN
# 9159                    NaN                          NaN
# 9160                    NaN                          NaN
# 9161                    NaN                          NaN
#
#      kidney loop of Henle ascending limb epithelial cell  \
# 0                                               Slc12a1
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...
# 9132                                                NaN
# 9133                                                NaN
# 9134                                                NaN
# 9135                                                NaN
# 9136                                                NaN
# 9137                                                NaN
# 9138                                                NaN
# 9139                                                NaN
# 9140                                                NaN
# 9141                                                NaN
# 9142                                                NaN
# 9143                                                NaN
# 9144                                                NaN
# 9145                                                NaN
# 9146                                                NaN
# 9147                                                NaN
# 9148                                                NaN
# 9149                                                NaN
# 9150                                                NaN
# 9151                                                NaN
# 9152                                                NaN
# 9153                                                NaN
# 9154                                                NaN
# 9155                                                NaN
# 9156                                                NaN
# 9157                                                NaN
# 9158                                                NaN
# 9159                                                NaN
# 9160                                                NaN
# 9161                                                NaN
#
#       kidney loop of Henle ascending limb epithelial cell_gini  \
# 0                                                   1.0
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...
# 9132                                                NaN
# 9133                                                NaN
# 9134                                                NaN
# 9135                                                NaN
# 9136                                                NaN
# 9137                                                NaN
# 9138                                                NaN
# 9139                                                NaN
# 9140                                                NaN
# 9141                                                NaN
# 9142                                                NaN
# 9143                                                NaN
# 9144                                                NaN
# 9145                                                NaN
# 9146                                                NaN
# 9147                                                NaN
# 9158              NaN                    NaN               Zxdc
# 9159              NaN                    NaN                Zyx
# 9160              NaN                    NaN               Zzz3
# 9161              NaN                    NaN  zsGreen_transgene
#
#       mesangial cell_gini B cell  B cell_gini  \
# 0            2.071603e-05   Ccr7     0.189172
# 1            8.220964e-07  Cd79a     0.360559
# 2            0.000000e+00   Ly6d     0.368927
# 3            0.000000e+00  Ms4a1     0.081342
# 4            0.000000e+00    NaN          NaN
# 5            0.000000e+00    NaN          NaN
# 6            0.000000e+00    NaN          NaN
# 7            0.000000e+00    NaN          NaN
# 8            0.000000e+00    NaN          NaN
# 9            2.743943e-05    NaN          NaN
# 10           4.275988e-05    NaN          NaN
# 11           0.000000e+00    NaN          NaN
# 12           0.000000e+00    NaN          NaN
# 13           0.000000e+00    NaN          NaN
# 14           8.747161e-05    NaN          NaN
# 15           0.000000e+00    NaN          NaN
# 16           0.000000e+00    NaN          NaN
# 17           1.440891e-05    NaN          NaN
# 18           2.134694e-05    NaN          NaN
# 19           0.000000e+00    NaN          NaN
# 20           1.412055e-05    NaN          NaN
# 21           0.000000e+00    NaN          NaN
# 22           0.000000e+00    NaN          NaN
# 23           0.000000e+00    NaN          NaN
# 24           0.000000e+00    NaN          NaN
# 25           0.000000e+00    NaN          NaN
# 26           3.802342e-05    NaN          NaN
# 27           0.000000e+00    NaN          NaN
# 28           0.000000e+00    NaN          NaN
# 29           0.000000e+00    NaN          NaN
# ...                   ...    ...          ...
# 9132         0.000000e+00    NaN          NaN
# 9133         0.000000e+00    NaN          NaN
# 9134         0.000000e+00    NaN          NaN
# 9135         0.000000e+00    NaN          NaN
# 9136         1.509168e-05    NaN          NaN
# 9137         0.000000e+00    NaN          NaN
# 9138         0.000000e+00    NaN          NaN
# 9139         2.575568e-04    NaN          NaN
# 9140         0.000000e+00    NaN          NaN
# 9141         1.204972e-04    NaN          NaN
# 9142         0.000000e+00    NaN          NaN
# 9143         5.182341e-05    NaN          NaN
# 9144         0.000000e+00    NaN          NaN
# 9145         0.000000e+00    NaN          NaN
# 9146         0.000000e+00    NaN          NaN
# 9147         3.090281e-05    NaN          NaN
# 9148         0.000000e+00    NaN          NaN
# 9149         9.749315e-05    NaN          NaN
# 9150         0.000000e+00    NaN          NaN
# 9151         0.000000e+00    NaN          NaN
# 9152         0.000000e+00    NaN          NaN
# 9153         1.251808e-04    NaN          NaN
# 9154         0.000000e+00    NaN          NaN
# 9155         0.000000e+00    NaN          NaN
# 9156         0.000000e+00    NaN          NaN
# 9157         3.706723e-05    NaN          NaN
# 9158         2.356257e-04    NaN          NaN
# 9159         1.316026e-04    NaN          NaN
# 9160         0.000000e+00    NaN          NaN
# 9161         0.000000e+00    NaN          NaN
#
#      kidney collecting duct epithelial cell  \
# 0                             0610005C13Rik
# 1                             0610007C21Rik
# 2                             0610007N19Rik
# 3                             0610007P14Rik
# 4                             0610009D07Rik
# 5                             0610010K14Rik
# 6                             0610010O12Rik
# 7                             0610011F06Rik
# 8                             0610012G03Rik
# 9                             0610012H03Rik
# 10                            0610031J06Rik
# 11                            0610037L13Rik
# 12                            0610038B21Rik
# 13                            0610040J01Rik
# 14                            0910001L09Rik
# 15                            1110001J03Rik
# 16                            1110002B05Rik
# 17                            1110003E01Rik
# 18                            1110004E09Rik
# 19                            1110004F10Rik
# 20                            1110008P14Rik
# 21                            1110014N23Rik
# 22                            1110017F19Rik
# 23                            1110018J18Rik
# 24                            1110028C15Rik
# 25                            1110032A03Rik
# 26                            1110034G24Rik
# 27                            1110038D17Rik
# 28                            1110038F14Rik
# 29                            1110049F12Rik
# ...                                     ...
# 9132                                    NaN
# 9133                                    NaN
# 9134                                    NaN
# 9135                                    NaN
# 9136                                    NaN
# 9137                                    NaN
# 9138                                    NaN
# 9139                                    NaN
# 9140                                    NaN
# 9141                                    NaN
# 9142                                    NaN
# 9143                                    NaN
# 9144                                    NaN
# 9145                                    NaN
# 9146                                    NaN
# 9147                                    NaN
# 9148                                    NaN
# 9149                                    NaN
# 9150                                    NaN
# 9151                                    NaN
# 9152                                    NaN
# 9153                                    NaN
# 9154                                    NaN
# 9155                                    NaN
# 9156                                    NaN
# 9157                                    NaN
# 9158                                    NaN
# 9159                                    NaN
# 9160                                    NaN
# 9161                                    NaN
#
#       kidney collecting duct epithelial cell_gini         T cell  T cell_gini  \
# 0                                        0.000239  0610007C21Rik     0.000042
# 1                                        0.000141  0610007L01Rik     0.000100
# 2                                        0.000100  0610007N19Rik     0.000000
# 3                                        0.000009  0610007P14Rik     0.000054
# 4                                        0.000067  0610007P22Rik     0.000050
# 5                                        0.000058  0610009D07Rik     0.000049
# 6                                        0.000241  0610010K14Rik     0.000012
# 7                                        0.000118  0610010O12Rik     0.000026
# 8                                        0.000125  0610031J06Rik     0.000095
# 9                                        0.000171  0610037P05Rik     0.000141
# 10                                       0.000161  0610040B10Rik     0.000000
# 11                                       0.000039  0910001L09Rik     0.000000
# 12                                       0.000053  1110001A16Rik     0.000018
# 13                                       0.000005  1110001J03Rik     0.000075
# 14                                       0.000218  1110002B05Rik     0.000017
# 15                                       0.000081  1110002L01Rik     0.000055
# 16                                       0.000049  1110003E01Rik     0.000016
# 17                                       0.000081  1110004E09Rik     0.000000
# 18                                       0.000111  1110007C09Rik     0.000000
# 19                                       0.000007  1110008F13Rik     0.000048
# 20                                       0.000056  1110008P14Rik     0.000109
# 21                                       0.000010  1110014N23Rik     0.000018
# 22                                       0.000073  1110032A03Rik     0.000011
# 23                                       0.000010  1110034A24Rik     0.000000
# 24                                       0.000065  1110034B05Rik     0.000000
# 25                                       0.000059  1110037F02Rik     0.000000
# 26                                       0.000046  1110038F14Rik     0.000020
# 27                                       0.000093  1110054O05Rik     0.000000
# 28                                       0.000018  1110065P20Rik     0.000000
# 29                                       0.000030  1190002F15Rik     0.000042
# ...                                           ...            ...          ...
# 9132                                          NaN            NaN          NaN
# 9133                                          NaN            NaN          NaN
# 9134                                          NaN            NaN          NaN
# 9135                                          NaN            NaN          NaN
# 9136                                          NaN            NaN          NaN
# 9137                                          NaN            NaN          NaN
# 9138                                          NaN            NaN          NaN
# 9139                                          NaN            NaN          NaN
# 9140                                          NaN            NaN          NaN
# 9141                                          NaN            NaN          NaN
# 9142                                          NaN            NaN          NaN
# 9143                                          NaN            NaN          NaN
# 9144                                          NaN            NaN          NaN
# 9145                                          NaN            NaN          NaN
# 9146                                          NaN            NaN          NaN
# 9147                                          NaN            NaN          NaN
# 9148                                          NaN            NaN          NaN
# 9149                                          NaN            NaN          NaN
# 9150                                          NaN            NaN          NaN
# 9151                                          NaN            NaN          NaN
# 9152                                          NaN            NaN          NaN
# 9153                                          NaN            NaN          NaN
# 9154                                          NaN            NaN          NaN
# 9155                                          NaN            NaN          NaN
# 9156                                          NaN            NaN          NaN
# 9157                                          NaN            NaN          NaN
# 9158                                          NaN            NaN          NaN
# 9159                                          NaN            NaN          NaN
# 9160                                          NaN            NaN          NaN
# 9161                                          NaN            NaN          NaN
#
#      kidney collecting duct principal cell  \
# 0                                      Clu
# 1                            D630042F21Rik
# 2                                    Pgam2
# 3                                  Slc12a3
# 4                                      NaN
# 5                                      NaN
# 6                                      NaN
# 7                                      NaN
# 8                                      NaN
# 9                                      NaN
# 10                                     NaN
# 11                                     NaN
# 12                                     NaN
# 13                                     NaN
# 14                                     NaN
# 15                                     NaN
# 16                                     NaN
# 17                                     NaN
# 18                                     NaN
# 19                                     NaN
# 20                                     NaN
# 21                                     NaN
# 22                                     NaN
# 23                                     NaN
# 24                                     NaN
# 25                                     NaN
# 26                                     NaN
# 27                                     NaN
# 28                                     NaN
# 29                                     NaN
# ...                                    ...
# 9132                                   NaN
# 9133                                   NaN
# 9134                                   NaN
# 9135                                   NaN
# 9136                                   NaN
# 9137                                   NaN
# 9138                                   NaN
# 9139                                   NaN
# 9140                                   NaN
# 9141                                   NaN
# 9142                                   NaN
# 9143                                   NaN
# 9144                                   NaN
# 9145                                   NaN
# 9146                                   NaN
# 9147                                   NaN
# 9148                                   NaN
# 9149                                   NaN
# 9150                                   NaN
# 9151                                   NaN
# 9152                                   NaN
# 9153                                   NaN
# 9154                                   NaN
# 9155                                   NaN
# 9156                                   NaN
# 9157                                   NaN
# 9158                                   NaN
# 9159                                   NaN
# 9160                                   NaN
# 9161                                   NaN
#
#       kidney collecting duct principal cell_gini     macrophage  \
# 0                                       0.120505  0610007N19Rik
# 1                                       0.153364  0610007P08Rik
# 2                                       0.439040  0610007P14Rik
# 3                                       0.287090  0610007P22Rik
# 4                                            NaN  0610008F07Rik
# 5                                            NaN  0610009B22Rik
# 6                                            NaN  0610009D07Rik
# 7                                            NaN  0610009L18Rik
# 8                                            NaN  0610009O20Rik
# 9                                            NaN  0610010B08Rik
# 10                                           NaN  0610010F05Rik
# 11                                           NaN  0610010K14Rik
# 12                                           NaN  0610010O12Rik
# 13                                           NaN  0610011F06Rik
# 14                                           NaN  0610011L14Rik
# 15                                           NaN  0610012G03Rik
# 16                                           NaN  0610012H03Rik
# 17                                           NaN  0610030E20Rik
# 18                                           NaN  0610031J06Rik
# 19                                           NaN  0610037P05Rik
# 20                                           NaN  0610038B21Rik
# 21                                           NaN  0610038L08Rik
# 22                                           NaN  0610039K10Rik
# 23                                           NaN  0610040B10Rik
# 24                                           NaN  0610040F04Rik
# 25                                           NaN  0610043K17Rik
# 26                                           NaN  0910001L09Rik
# 27                                           NaN      100043387
# 28                                           NaN  1100001G20Rik
# 29                                           NaN  1110001J03Rik
# ...                                          ...            ...
# 9132                                         NaN            NaN
# 9133                                         NaN            NaN
# 9134                                         NaN            NaN
# 9135                                         NaN            NaN
# 9136                                         NaN            NaN
# 9137                                         NaN            NaN
# 9138                                         NaN            NaN
# 9139                                         NaN            NaN
# 9140                                         NaN            NaN
# 9141                                         NaN            NaN
# 9142                                         NaN            NaN
# 9143                                         NaN            NaN
# 9144                                         NaN            NaN
# 9145                                         NaN            NaN
# 9146                                         NaN            NaN
# 9147                                         NaN            NaN
# 9148                                         NaN            NaN
# 9149                                         NaN            NaN
# 9150                                         NaN            NaN
# 9151                                         NaN            NaN
# 9152                                         NaN            NaN
# 9153                                         NaN            NaN
# 9154                                         NaN            NaN
# 9155                                         NaN            NaN
# 9156                                         NaN            NaN
# 9157                                         NaN            NaN
# 9158                                         NaN            NaN
# 9159                                         NaN            NaN
# 9160                                         NaN            NaN
# 9161                                         NaN            NaN
#
#       macrophage_gini epithelial cell of proximal tubule  \
# 0            0.000000                      0610005C13Rik
# 1            0.000000                      0610007C21Rik
# 2            0.000015                      0610007L01Rik
# 3            0.000000                      0610007N19Rik
# 4            0.000000                      0610007P14Rik
# 5            0.000013                      0610009B22Rik
# 6            0.000014                      0610009D07Rik
# 7            0.000000                      0610010K14Rik
# 8            0.000000                      0610010O12Rik
# 9            0.000000                      0610011F06Rik
# 10           0.000010                      0610012G03Rik
# 11           0.000009                      0610012H03Rik
# 12           0.000007                      0610031J06Rik
# 13           0.000000                      0610031O16Rik
# 14           0.000000                      0610037P05Rik
# 15           0.000018                      0910001L09Rik
# 16           0.000000                      1110001A16Rik
# 17           0.000000                      1110001J03Rik
# 18           0.000018                      1110002B05Rik
# 19           0.000000                      1110003E01Rik
# 20           0.000000                      1110004E09Rik
# 21           0.000000                      1110004F10Rik
# 22           0.000000                      1110007C09Rik
# 23           0.000000                      1110008F13Rik
# 24           0.000000                      1110008P14Rik
# 25           0.000000                      1110017F19Rik
# 26           0.000000                      1110019D14Rik
# 27           0.000017                      1110020G09Rik
# 28           0.000011                      1110028C15Rik
# 29           0.000000                      1110032A03Rik
# ...               ...                                ...
# 9132              NaN                                NaN
# 9133              NaN                                NaN
# 9134              NaN                                NaN
# 9135              NaN                                NaN
# 9136              NaN                                NaN
# 9137              NaN                                NaN
# 9138              NaN                                NaN
# 9139              NaN                                NaN
# 9140              NaN                                NaN
# 9141              NaN                                NaN
# 9142              NaN                                NaN
# 9143              NaN                                NaN
# 9144              NaN                                NaN
# 9145              NaN                                NaN
# 9146              NaN                                NaN
# 9147              NaN                                NaN
# 9148              NaN                                NaN
# 9149              NaN                                NaN
# 9150              NaN                                NaN
# 9151              NaN                                NaN
# 9152              NaN                                NaN
# 9153              NaN                                NaN
# 9154              NaN                                NaN
# 9155              NaN                                NaN
# 9156              NaN                                NaN
# 9157              NaN                                NaN
# 9158              NaN                                NaN
# 9159              NaN                                NaN
# 9160              NaN                                NaN
# 9161              NaN                                NaN
#
#       epithelial cell of proximal tubule_gini
# 0                                    0.000076
# 1                                    0.000065
# 2                                    0.000068
# 3                                    0.000084
# 4                                    0.000011
# 5                                    0.000019
# 6                                    0.000085
# 7                                    0.000106
# 8                                    0.000095
# 9                                    0.000435
# 10                                   0.000116
# 11                                   0.000904
# 12                                   0.000038
# 13                                   0.000003
# 14                                   0.000137
# 15                                   0.000173
# 16                                   0.000020
# 17                                   0.000181
# 18                                   0.000112
# 19                                   0.000084
# 20                                   0.000024
# 21                                   0.000067
# 22                                   0.000100
# 23                                   0.000095
# 24                                   0.000058
# 25                                   0.000084
# 26                                   0.000116
# 27                                   0.000016
# 28                                   0.000019
# 29                                   0.000086
# ...                                       ...
# 9132                                      NaN
# 9133                                      NaN
# 9134                                      NaN
# 9135                                      NaN
# 9136                                      NaN
# 9137                                      NaN
# 9138                                      NaN
# 9139                                      NaN
# 9140                                      NaN
# 9141                                      NaN
# 9142                                      NaN
# 9143                                      NaN
# 9144                                      NaN
# 9145                                      NaN
# 9146                                      NaN
# 9147                                      NaN
# 9148                                      NaN
# 9149                                      NaN
# 9150                                      NaN
# 9151                                      NaN
# 9152                                      NaN
# 9153                                      NaN
# 9154                                      NaN
# 9155                                      NaN
# 9156                                      NaN
# 9157                                      NaN
# 9158                                      NaN
# 9159                                      NaN
# 9160                                      NaN
# 9161                                      NaN
#
# [9162 rows x 20 columns]

# %%
results_celltype_cv.to_csv('KidneyFacsCell1000TissReset.csv')

# %%
tiss.obs

# %% [markdown]
# # Age, Heart

# %%
adata = read_h5ad('/Users/madelinepark/Downloads/Heart_droplet.h5ad')
tiss = adata

# %%
results_age_cv = pd.DataFrame() #create results data frame 

for c in list(set(tiss.obs['age'])): 
    print(c)
    age_of_interest = c
    tiss.obs['age_type_of_interest'] = 'rest' #moved into, was outside before
    tiss.obs.loc[tiss.obs['age'] == age_of_interest,'age_type_of_interest'] = age_of_interest

    clf = RandomForestClassifier(n_estimators=1000, random_state=0, n_jobs=-1, oob_score=True)
    selector = RFECV(clf, step=0.2, cv=3, n_jobs=4) # step = % rounded down at each iteration  
    
# #     tiss.obs.loc[tiss.obs[tiss.obs['age'] == age_of_interest].index,'age_type_of_interest'] = age_of_interest
#     tiss.obs.loc[tiss.obs['age'] == age_of_interest,'age_type_of_interest'] = age_of_interest

    feat_labels = tiss.var_names 
    X = tiss.X
    y = tiss.obs['age_type_of_interest']
    
    print('training...')
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05, random_state=0) 
    clf.fit(X_train, y_train)
    selector.fit(X_train, y_train)
    feature_selected = feat_labels[selector.support_] 
    
    print('result writing')
    column_headings = []
    column_headings.append(c)
    column_headings.append(c + '_gini')
    
    resaux = pd.DataFrame(columns=column_headings)
    resaux[c] = feature_selected
    resaux[c + '_gini'] = (selector.estimator_.feature_importances_)
    
    print(feature_selected)
    print (selector.estimator_.feature_importances_)
    
    results_age_cv = pd.concat([results_age_cv,resaux],axis=1)
    
    #adding this smart cheeky line
    print(list(set(tiss.obs['age_type_of_interest'])))
    
    tiss.obs['age_type_of_interest'] = 'rest'
    
results_age_cv
# Out:
# 24m
# training...
# result writing
# Index(['Sox17', 'Tcea1', 'Rb1cc1', 'Pcmtd1', 'Snhg6', 'Cops5', 'Tram1', 'Eya1',
#        'Rpl7', 'Ube2w',
#        ...
#        'Rbbp7', 'Bmx', 'Pir', 'Figf', 'Tmsb4x', 'Kdm5d', 'Eif2s3y', 'Uty',
#        'Ddx3y', 'Erdr1'],
#       dtype='object', name='index', length=3972)
# [0.00013201 0.00021865 0.00011146 ... 0.00028555 0.00272545 0.00143913]
# ['rest', '24m']
# 30m
# training...
# result writing
# Index(['Sox17', 'Mrpl15', 'Lypla1', 'Tcea1', 'Rb1cc1', 'Pcmtd1', 'Snhg6',
#        'Prex2', 'Tram1', 'Gm5523',
#        ...
#        'Rbbp7', 'Zrsr2', 'Gpm6b', 'Rab9', 'Tmsb4x', 'Mid1', 'Vamp7', 'Eif2s3y',
#        'Ddx3y', 'Erdr1'],
#       dtype='object', name='index', length=3972)
# [1.39486771e-04 8.48414190e-05 8.22038217e-05 ... 1.08456808e-03
#  9.17215743e-04 1.33128649e-04]
# ['rest', '30m']
# 18m
# training...
# result writing
# Index(['Tcea1', 'Rb1cc1', 'Pcmtd1', 'Sgk3', 'Sulf1', 'Ncoa2', 'Tram1', 'Eya1',
#        'Rpl7', 'Tceb1',
#        ...
#        'Pir', 'Gemin8', 'Rab9', 'Tmsb4x', 'Tlr7', 'Prps2', 'G530011O06Rik',
#        'Eif2s3y', 'Ddx3y', 'Erdr1'],
#       dtype='object', name='index', length=3972)
# [0.00019166 0.00021225 0.00022055 ... 0.00045967 0.00055771 0.00082472]
# ['rest', '18m']
# 21m
# training...
# result writing
# Index(['Sox17', 'Mrpl15', 'Lypla1', 'Pcmtd1', 'Rrs1', 'Snhg6', 'Tram1', 'Rpl7',
#        'Tceb1', 'Tmem70',
#        ...
#        'Pir', 'Figf', 'Trappc2', 'Tmsb4x', 'Hccs', 'Mid1', 'G530011O06Rik',
#        'Eif2s3y', 'Ddx3y', 'Erdr1'],
#       dtype='object', name='index', length=3972)
# [1.47796351e-04 9.13322072e-05 1.36625927e-04 ... 2.08412671e-03
#  4.51404567e-03 2.69696950e-03]
# ['rest', '21m']
# 1m
# training...
# result writing
# Index(['Dbp'], dtype='object', name='index')
# [1.]
# ['rest', '1m']
# 3m
# training...
# result writing
# Index(['Tcea1', 'Rb1cc1', 'Pcmtd1', 'Vcpip1', 'Snhg6', 'Arfgef1', 'Prex2',
#        'Sulf1', 'Tram1', 'Lactb2',
#        ...
#        'Pir', 'Mospd2', 'Gpm6b', 'Rab9', 'Tmsb4x', 'Tlr8', 'Msl3', 'Vamp7',
#        'Eif2s3y', 'Ddx3y'],
#       dtype='object', name='index', length=3972)
# 3955        Kctd12b  0.000257           Sat1  0.000158  2210013O21Rik
# 3956  2210013O21Rik  0.000231          Acot9  0.000090           Sat1
# 3957           Sat1  0.000305          Prdx4  0.000127          Prdx4
# 3958          Prdx4  0.000308           Smpx  0.000139         Eif1ax
# 3959            Sms  0.000192         Eif1ax  0.000080          Pdha1
# 3960           Rai2  0.000177        Sh3kbp1  0.000084          Rbbp7
# 3961          Reps2  0.000153          Pdha1  0.000167          Ctps2
# 3962          Rbbp7  0.000267          Rbbp7  0.000081            Pir
# 3963            Bmx  0.000161          Zrsr2  0.000053         Gemin8
# 3964            Pir  0.000331          Gpm6b  0.000131           Rab9
# 3965           Figf  0.000192           Rab9  0.000085         Tmsb4x
# 3966         Tmsb4x  0.000394         Tmsb4x  0.000965           Tlr7
# 3967          Kdm5d  0.000200           Mid1  0.000069          Prps2
# 3968        Eif2s3y  0.002069          Vamp7  0.000068  G530011O06Rik
# 3969            Uty  0.000286        Eif2s3y  0.001085        Eif2s3y
# 3970          Ddx3y  0.002725          Ddx3y  0.000917          Ddx3y
# 3971          Erdr1  0.001439          Erdr1  0.000133          Erdr1
#
#       18m_gini            21m  21m_gini   1m  1m_gini             3m   3m_gini
# 0     0.000192          Sox17  0.000148  Dbp      1.0          Tcea1  0.000329
# 1     0.000212         Mrpl15  0.000091  NaN      NaN         Rb1cc1  0.000381
# 2     0.000221         Lypla1  0.000137  NaN      NaN         Pcmtd1  0.000152
# 3     0.000234         Pcmtd1  0.000140  NaN      NaN         Vcpip1  0.000188
# 4     0.000155           Rrs1  0.000141  NaN      NaN          Snhg6  0.000092
# 5     0.000209          Snhg6  0.000115  NaN      NaN        Arfgef1  0.000130
# 6     0.000159          Tram1  0.000199  NaN      NaN          Prex2  0.000533
# 7     0.000101           Rpl7  0.000343  NaN      NaN          Sulf1  0.000277
# 8     0.000339          Tceb1  0.000189  NaN      NaN          Tram1  0.000228
# 9     0.000159         Tmem70  0.000120  NaN      NaN         Lactb2  0.000347
# 10    0.000090           Mcm3  0.000101  NaN      NaN          Terf1  0.000122
# 11    0.000151          Gsta3  0.000114  NaN      NaN           Rpl7  0.000383
# 12    0.000140         Lmbrd1  0.000142  NaN      NaN          Ube2w  0.000132
# 13    0.000137            Dst  0.000290  NaN      NaN           Pi15  0.000180
# 14    0.000133        Ccdc115  0.000086  NaN      NaN          Tram2  0.000303
# 15    0.000167           Imp4  0.000102  NaN      NaN          Gsta3  0.000091
# 16    0.000194         Ptpn18  0.000121  NaN      NaN          Smap1  0.000120
# 17    0.000362        Plekhb2  0.000161  NaN      NaN         Lmbrd1  0.000092
# 18    0.000179          Cox5b  0.000269  NaN      NaN           Phf3  0.000231
# 19    0.000174          Unc50  0.000186  NaN      NaN         Zfp451  0.000182
# 20    0.000153         Mrpl30  0.000167  NaN      NaN            Dst  0.000690
# 21    0.000080         Txndc9  0.000158  NaN      NaN           Imp4  0.000121
# 22    0.000218          Eif5b  0.000157  NaN      NaN        Plekhb2  0.000106
# 23    0.000129          Pdcl3  0.000190  NaN      NaN          Uggt1  0.000147
# 24    0.000127          Rpl31  0.000336  NaN      NaN         Lman2l  0.000063
# 25    0.000162           Fhl2  0.000278  NaN      NaN          Cox5b  0.000279
# 26    0.000252          Gulp1  0.000094  NaN      NaN         Mrpl30  0.000189
# 27    0.000106         Col3a1  0.000315  NaN      NaN          Eif5b  0.000200
# 28    0.000216         Col5a2  0.000096  NaN      NaN           Rev1  0.000162
# 29    0.000350           Sdpr  0.000181  NaN      NaN           Aff3  0.000283
# ...        ...            ...       ...  ...      ...            ...       ...
# 3942  0.000415        Tsc22d3  0.000237  NaN      NaN         Col4a5  0.000585
# 3943  0.000156         Maged2  0.000192  NaN      NaN        Tmem164  0.000114
# 3944  0.000158        Fam120c  0.000074  NaN      NaN           Pak3  0.000123
# 3945  0.000139          Huwe1  0.000169  NaN      NaN         Maged2  0.000108
# 3946  0.000132       Hsd17b10  0.000138  NaN      NaN           Phf8  0.000138
# 3947  0.000274          Smc1a  0.000151  NaN      NaN          Huwe1  0.000144
# 3948  0.000169          Kdm5c  0.000277  NaN      NaN          Smc1a  0.000473
# 3949  0.000214         Mageh1  0.000189  NaN      NaN          Kdm5c  0.000183
# 3950  0.000201         Ubqln2  0.000142  NaN      NaN         Tspyl2  0.000159
# 3951  0.000195  2210013O21Rik  0.000139  NaN      NaN         Mageh1  0.000078
# 3952  0.000152           Sat1  0.000243  NaN      NaN         Ubqln2  0.000137
# 3953  0.000124          Acot9  0.000090  NaN      NaN           Sat1  0.000188
# 3954  0.000119          Prdx4  0.000276  NaN      NaN          Prdx4  0.000117
# 3955  0.000129         Mbtps2  0.000121  NaN      NaN        Rps6ka3  0.000577
# 3956  0.000284           Smpx  0.001292  NaN      NaN         Eif1ax  0.000138
# 3957  0.000247          Pdha1  0.000200  NaN      NaN  A830080D01Rik  0.000170
# 3958  0.000161          Rbbp7  0.000209  NaN      NaN        Sh3kbp1  0.000468
# 3959  0.000138          Syap1  0.000099  NaN      NaN          Pdha1  0.000224
# 3960  0.000138          Ctps2  0.000148  NaN      NaN          Syap1  0.000130
# 3961  0.000147          Zrsr2  0.000132  NaN      NaN            Bmx  0.000199
# 3962  0.000167            Pir  0.000158  NaN      NaN            Pir  0.000110
# 3963  0.000128           Figf  0.000107  NaN      NaN         Mospd2  0.000273
# 3964  0.000120        Trappc2  0.000078  NaN      NaN          Gpm6b  0.000130
# 3965  0.000570         Tmsb4x  0.000348  NaN      NaN           Rab9  0.000129
# 3966  0.000166           Hccs  0.000115  NaN      NaN         Tmsb4x  0.000440
# 3967  0.000093           Mid1  0.002389  NaN      NaN           Tlr8  0.000639
# 3968  0.000250  G530011O06Rik  0.000564  NaN      NaN           Msl3  0.000365
# 3969  0.000460        Eif2s3y  0.002084  NaN      NaN          Vamp7  0.000323
# 3970  0.000558          Ddx3y  0.004514  NaN      NaN        Eif2s3y  0.000381
# 3971  0.000825          Erdr1  0.002697  NaN      NaN          Ddx3y  0.001392
#
# [3972 rows x 12 columns]

# %%
results_age_cv.to_csv('HeartDropletAge1000TissReset.csv')
