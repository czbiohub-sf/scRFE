# %%
pwd
# Out:
# '/Users/madelinepark/srcBio/scRFE/scripts'

# %% [markdown]
# # scRFE giniPlots code

# %% [markdown]
# ## Setup

# %%
import scanpy as sc
import pandas as pd

sc.settings.verbosity = 3

# %%
import seaborn as sns

import matplotlib.pyplot as plt
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42

# show figures in the notebook
# %matplotlib inline 


# sc.settings.set_figure_params(dpi=300) # save umaps as non-vectorial hi-res images
# # plt.rcParams['figure.figsize']=(10,10) # make figures square if not using the setting above

# show figures in the notebook
# %matplotlib inline

# %%
import sys

# %%
import os

# %% [markdown]
# ## Make plots for facsTissAge5000

# %%
facsTissueList = ['SCAT','Large_Intestine','Diaphragm','Marrow','Mammary_Gland','Pancreas',
                  'Lung', 'Bladder', 'MAT','Tongue','Spleen','Skin','Limb_Muscle','Trachea',
                  'GAT','Thymus','Liver','Kidney','Heart','Brain_Myeloid','Brain_Non-Myeloid',
                  'Aorta','BAT']
facsTissAgetfsResults = {}
for t in facsTissueList:
    facsTissAgetfsResults[t] = pd.read_csv(t+'_facs_tf_age_5000.csv')

# %%
facsTissAgetfsResults
# Out:
# {'SCAT':      Unnamed: 0     18m  18m_gini    24m  24m_gini      3m   3m_gini
#  0             0    Jund  0.025855   Jund  0.049475    Jund  0.070863
#  1             1   Klf13  0.013727   Sub1  0.021063    Junb  0.016003
#  2             2  Hivep2  0.011582    Fos  0.017455   Aebp1  0.013765
#  3             3    Junb  0.011428   Nfia  0.017351   Klf13  0.013204
#  4             4  Hnrnpk  0.010090  Mndal  0.017281    Ier2  0.010848
#  ..          ...     ...       ...    ...       ...     ...       ...
#  632         632     NaN       NaN    NaN       NaN  Zfp831  0.000241
#  633         633     NaN       NaN    NaN       NaN  Zfp382  0.000239
#  634         634     NaN       NaN    NaN       NaN   Zfp60  0.000237
#  635         635     NaN       NaN    NaN       NaN   Hoxb3  0.000226
#  636         636     NaN       NaN    NaN       NaN   Tead3  0.000224
#
#  [637 rows x 7 columns],
#  'Large_Intestine':       Unnamed: 0      18m  18m_gini            24m  24m_gini      3m   3m_gini
#  0              0     Jund  0.024094        Gpbp1l1  0.013801    Jund  0.068339
#  1              1     Cdx1  0.018017           Jund  0.012722     Jun  0.023272
#  2              2   Hmg20b  0.013038           Tle4  0.011180    Ybx1  0.022859
#  3              3     Ybx1  0.011651          Nr3c2  0.010980  Hmg20b  0.021887
#  4              4     Ier2  0.010354          Klf10  0.009746    Cdx1  0.019147
#  ...          ...      ...       ...            ...       ...     ...       ...
#  1056        1056     Vax1  0.000000           Cdx4  0.000000     NaN       NaN
#  1057        1057      Sry  0.000000           Helt  0.000000     NaN       NaN
#  1058        1058  Zscan4f  0.000000  2410141K09Rik  0.000000     NaN       NaN
#  1059        1059     Lbx1  0.000000         Nkx3-2  0.000000     NaN       NaN
#  1060        1060     Mycs  0.000000           Lbx1  0.000000     NaN       NaN
#
#  [1061 rows x 7 columns],
#  'Diaphragm':       Unnamed: 0    18m  18m_gini      24m  24m_gini      3m   3m_gini
#  0              0   Nfe2  0.023474   Hnrnpk  0.027646  Hnrnpk  0.024727
#  1              1  Hmgb2  0.021183     Cnbp  0.021207    Cnbp  0.023921
#  2              2   Btg2  0.013188    Klf13  0.018148    Skil  0.016075
#  3              3   Irf8  0.011641     Med1  0.017972    Tcf4  0.015969
#  4              4   Junb  0.010657  Tsc22d3  0.014941   Gpbp1  0.015510
#  ...          ...    ...       ...      ...       ...     ...       ...
#  1056        1056    NaN       NaN    Nr0b1  0.000000   Nr0b1  0.000000
#  1057        1057    NaN       NaN   Phox2b  0.000000    Lhx3  0.000000
#  1058        1058    NaN       NaN     Spz1  0.000000   Snai3  0.000000
#  1059        1059    NaN       NaN      Sry  0.000000  Nkx2-5  0.000000
#  1060        1060    NaN       NaN     Gsx1  0.000000    Mnx1  0.000000
#
#  [1061 rows x 7 columns],
#  'Marrow':      Unnamed: 0      18m  18m_gini      24m  24m_gini       3m   3m_gini
#  0             0     Jund  0.034604     Ets1  0.023334     Jund  0.027738
#  1             1      Fos  0.022766    Gpbp1  0.021693    Ikzf1  0.020799
#  2             2    Klf13  0.018745  Gpbp1l1  0.020319    Gpbp1  0.020644
#  3             3     Fosb  0.016849    Stag2  0.019256     Ybx1  0.018593
#  4             4  Tsc22d4  0.014928      Sp3  0.017214  Gpbp1l1  0.016625
#  ..          ...      ...       ...      ...       ...      ...       ...
#  208         208      Sp2  0.002560   Csrnp1  0.001994    Nfkb2  0.002182
#  209         209     Nfyb  0.002536     Elk4  0.001971    Gtf3a  0.002149
#  210         210   Bmpr1a  0.002455    Sirt1  0.001922    Rreb1  0.002126
#  211         211      Id1  0.002220     Ets2  0.001920  Zfp518a  0.002056
#  212         212    Sox17  0.002191  Zfp518a  0.001834    Sirt1  0.002031
#
#  [213 rows x 7 columns],
#  'Mammary_Gland':      Unnamed: 0    18m  18m_gini     21m  21m_gini     3m   3m_gini
#  0             0   Jund  0.088622    Jund  0.061976   Jund  0.169418
#  1             1   Junb  0.054230    Sub1  0.017586   Junb  0.048704
#  2             2   Skil  0.029693    Junb  0.016371   Ier2  0.034026
#  3             3  Nr4a1  0.028555   Cebpb  0.016326  Cebpb  0.031439
#  4             4   Atf3  0.026276    Bcl3  0.014409  Nr4a1  0.026686
#  ..          ...    ...       ...     ...       ...    ...       ...
#  844         844    NaN       NaN   Gata5  0.000018    NaN       NaN
#  845         845    NaN       NaN    Tal2  0.000017    NaN       NaN
#  846         846    NaN       NaN  Pou2f2  0.000015    NaN       NaN
#  847         847    NaN       NaN   Dach2  0.000013    NaN       NaN
#  848         848    NaN       NaN    Dlx2  0.000011    NaN       NaN
#
#  [849 rows x 7 columns],
#  'Pancreas':      Unnamed: 0     18m  18m_gini      24m  24m_gini       3m   3m_gini
#  0             0    Atf5  0.021484     Jund  0.046113     Jund  0.075086
#  1             1     Fos  0.018357    Stag2  0.024131    Stag2  0.013739
#  2             2    Jund  0.018056  Gpbp1l1  0.018752  Creb3l2  0.013406
#  3             3    Egr1  0.015141    Clock  0.018138  Hnrnpab  0.012992
#  4             4    Hsf2  0.012721    Strn3  0.017500     Mafb  0.012572
#  ..          ...     ...       ...      ...       ...      ...       ...
#  208         208  Srebf2  0.002758     Hsf1  0.002242    Nr1d1  0.002397
#  209         209  Gtf3c5  0.002722    Dmtf1  0.002177   Zbtb16  0.002370
#  210         210    Thra  0.002700    Nr1h2  0.002164  Zfp518a  0.002314
#  211         211  Tcf7l1  0.002644   Zfp668  0.002155     Irf8  0.002255
#  212         212   Rbpjl  0.002612   Zfp386  0.002131    Taf9b  0.002164
#
#  [213 rows x 7 columns],
#  'Lung':       Unnamed: 0     18m  18m_gini     24m  24m_gini     3m   3m_gini
#  0              0    Jund  0.048164     Jun  0.029188   Jund  0.040111
#  1              1     Jun  0.040361  Hnrnpk  0.022554    Fos  0.023390
#  2              2  Hnrnpk  0.026139    Junb  0.019824   Nfia  0.019728
#  3              3    Junb  0.018795  Ctnnb1  0.013509  Ncoa3  0.018935
#  4              4   Smad6  0.017987    Ets1  0.012721   Btg2  0.016303
#  ...          ...     ...       ...     ...       ...    ...       ...
#  1056        1056     NaN       NaN    Sox1  0.000000    NaN       NaN
#  1057        1057     NaN       NaN    Gsx1  0.000000    NaN       NaN
#  1058        1058     NaN       NaN    Dlx2  0.000000    NaN       NaN
#  1059        1059     NaN       NaN    Tlx2  0.000000    NaN       NaN
#  1060        1060     NaN       NaN  Hoxc11  0.000000    NaN       NaN
#
#  [1061 rows x 7 columns],
#  'Bladder':      Unnamed: 0       18m  18m_gini      24m  24m_gini      3m   3m_gini
#  0             0     Fosl1  0.030000     Jund  0.048352   Fosl1  0.047579
#  1             1      Pura  0.025263     Klf5  0.027283    Jund  0.038289
#  2             2      Xbp1  0.025072  Hnrnpab  0.024530    Klf5  0.029426
#  3             3     Taf10  0.020981   Ctnnb1  0.022850    Ybx1  0.026660
#  4             4       Erf  0.020558    Hmga1  0.018310   Hmga1  0.020177
#  ..          ...       ...       ...      ...       ...     ...       ...
#  208         208      Tle4  0.002234   Jarid2  0.001907    Egr2  0.001908
#  209         209  Gtf2ird1  0.002182     Irf2  0.001900    Zeb1  0.001907
#  210         210     Deaf1  0.002165   Zfp292  0.001862    Hic1  0.001904
#  211         211     Foxj2  0.002053    Trps1  0.001826  Zbtb38  0.001898
#  212         212     Rreb1  0.001838     Gli2  0.001623   Aebp1  0.001834
#
#  [213 rows x 7 columns],
#  'MAT':      Unnamed: 0     18m  18m_gini      24m  24m_gini      3m   3m_gini
#  0             0    Jund  0.032776     Jund  0.030926    Jund  0.072841
#  1             1   Klf13  0.026345     Bcl6  0.019779   Klf13  0.027453
#  2             2    Junb  0.013813     Sub1  0.013380    Junb  0.021067
#  3             3    Ier2  0.012595   Ctnnb1  0.012009    Ier2  0.015704
#  4             4   Pcbp1  0.009036  Tsc22d3  0.010671  Hivep2  0.013599
#  ..          ...     ...       ...      ...       ...     ...       ...
#  632         632    Lcor  0.000229      NaN       NaN   Nfxl1  0.000234
#  633         633     Myb  0.000222      NaN       NaN   Foxc2  0.000234
#  634         634   Foxd2  0.000221      NaN       NaN  Nfe2l3  0.000233
#  635         635  Zfp568  0.000211      NaN       NaN     Vdr  0.000229
#  636         636    Hey1  0.000208      NaN       NaN  Zfp438  0.000227
#
#  [637 rows x 7 columns],
#  'Tongue':      Unnamed: 0     18m  18m_gini      24m  24m_gini      3m   3m_gini
#  0             0    Jund  0.056305    Klf10  0.035656    Jund  0.076486
#  1             1   Pitx1  0.029660   Ctnnb1  0.034487  Ctnnb1  0.051771
#  2             2   Klf13  0.029399   Hnrnpk  0.031267   Hif1a  0.039257
#  3             3    Klf5  0.017603     Klf5  0.026659  Hnrnpk  0.037651
#  4             4  Ctnnb1  0.013163  Gpbp1l1  0.022365   Pitx1  0.028968
#  ..          ...     ...       ...      ...       ...     ...       ...
#  208         208    Sox9  0.002037     Elf2  0.001903   Zfp46  0.001446
#  209         209  Hivep1  0.001994   Zfp750  0.001851   Tshz1  0.001444
#  210         210    Spen  0.001985    Foxa1  0.001847   Arntl  0.001418
#  211         211    Etv4  0.001874    Zfp46  0.001829    Rest  0.001401
#  212         212   Nr1d2  0.001833    Snai2  0.001758  Hivep1  0.001323
#
#  [213 rows x 7 columns],
#  'Spleen':       Unnamed: 0     18m  18m_gini      24m  24m_gini       3m   3m_gini
#  0              0    Jund  0.018658     Jund  0.034584     Jund  0.067175
#  1              1    Ybx1  0.015982     Ets1  0.023663     Ets1  0.024492
#  2              2  Hnrnpk  0.012101    Ncoa3  0.019489     Ybx1  0.022984
#  3              3    Skil  0.011374     Atf3  0.016681   Pou2f2  0.017894
#  4              4    Junb  0.010814  Tsc22d3  0.014467  Tsc22d3  0.014269
#  ...          ...     ...       ...      ...       ...      ...       ...
#  1056        1056  Sohlh1  0.000000      NaN       NaN    Foxd3  0.000000
#  1057        1057  Zfp641  0.000000      NaN       NaN    Mesp1  0.000000
#  1058        1058   Foxn4  0.000000      NaN       NaN      Sry  0.000000
#  1059        1059   Nr0b1  0.000000      NaN       NaN    Foxd1  0.000000
#  1060        1060   Foxi2  0.000000      NaN       NaN   Ferd3l  0.000000
#
#  [1061 rows x 7 columns],
#  'Skin':       Unnamed: 0     18m  18m_gini      24m  24m_gini       3m   3m_gini
#  0              0    Jund  0.048259      Jun  0.025373     Jund  0.096358
#  1              1    Cnbp  0.019926    Klf10  0.023875   Hnrnpk  0.049623
#  2              2  Hnrnpk  0.018090     Btg2  0.017055     Cnbp  0.030807
#  3              3  Gatad1  0.017144  Gpbp1l1  0.016752     Ybx1  0.029730
#  4              4   Klf13  0.016559     Tle4  0.015549  Tsc22d3  0.026492
#  ...          ...     ...       ...      ...       ...      ...       ...
#  1056        1056   Foxi2  0.000000      NaN       NaN      NaN       NaN
#  1057        1057    Lbx1  0.000000      NaN       NaN      NaN       NaN
#  1058        1058   Foxl2  0.000000      NaN       NaN      NaN       NaN
#  1059        1059   Nr0b1  0.000000      NaN       NaN      NaN       NaN
#  1060        1060  Nkx2-6  0.000000      NaN       NaN      NaN       NaN
#
#  [1061 rows x 7 columns],
#  'Limb_Muscle':      Unnamed: 0    18m  18m_gini     24m  24m_gini      3m   3m_gini
#  0             0   Nfe2  0.023479  Hnrnpk  0.018716    Jund  0.062138
#  1             1   Jund  0.016302   Cebpd  0.018374  Hnrnpk  0.050638
#  2             2  Cebpe  0.014881   Ctbp1  0.016175  Ctnnb1  0.024687
#  3             3   Lmo2  0.014184    Tcf4  0.015619   Cebpd  0.022571
#  4             4  Hmgb2  0.013361  Ctnnb1  0.015321  Zbtb20  0.022192
#  ..          ...    ...       ...     ...       ...     ...       ...
#  844         844    NaN       NaN  Nkx3-2  0.000025     NaN       NaN
#  845         845    NaN       NaN  Zfp287  0.000025     NaN       NaN
#  846         846    NaN       NaN  Zfp493  0.000024     NaN       NaN
#  847         847    NaN       NaN   Zfp82  0.000022     NaN       NaN
#  848         848    NaN       NaN    Klf8  0.000020     NaN       NaN
#
#  [849 rows x 7 columns],
#  'Trachea':      Unnamed: 0      18m  18m_gini      24m  24m_gini       3m   3m_gini
#  0             0     Jund  0.028201    Gpbp1  0.015185   Ctnnb1  0.016025
#  1             1     Junb  0.017095    Stag2  0.015156   Zbtb20  0.015997
#  2             2  Hnrnpab  0.015924    Klf10  0.013434     Mafk  0.015320
#  3             3     Cnbp  0.013081  Bhlhe40  0.012556   Hnrnpk  0.014423
#  4             4   Zbtb16  0.012371     Btg2  0.010589    Nr1d1  0.014364
#  ..          ...      ...       ...      ...       ...      ...       ...
#  632         632      NaN       NaN   Zfp930  0.000234   Zfp629  0.000251
#  633         633      NaN       NaN   Zfp707  0.000232  Ighmbp2  0.000249
#  634         634      NaN       NaN    Hoxa4  0.000232    Sox17  0.000244
#  635         635      NaN       NaN   Zfp937  0.000219    Runx2  0.000237
#  636         636      NaN       NaN     Heyl  0.000218    Prox2  0.000227
#
#  [637 rows x 7 columns],
#  'GAT':      Unnamed: 0    18m  18m_gini      24m  24m_gini     3m   3m_gini
#  0             0   Jund  0.071723     Jund  0.017408   Jund  0.117584
#  1             1  Klf13  0.033965  Gpbp1l1  0.013034  Klf13  0.035248
#  2             2  Pcbp1  0.018397     Bcl6  0.011531   Bcl6  0.019040
#  3             3   Ybx1  0.017838     Junb  0.011042   Ybx1  0.016437
#  4             4   Sub1  0.010397     Sub1  0.010987   Fosb  0.015906
#  ..          ...    ...       ...      ...       ...    ...       ...
#  844         844    NaN       NaN     Klf1  0.000030    NaN       NaN
#  845         845    NaN       NaN      Mkx  0.000028    NaN       NaN
#  846         846    NaN       NaN   Zfp879  0.000027    NaN       NaN
#  847         847    NaN       NaN    Hmga2  0.000027    NaN       NaN
#  848         848    NaN       NaN   Dmrta1  0.000020    NaN       NaN
#
#  [849 rows x 7 columns],
#  'Thymus':      Unnamed: 0      18m  18m_gini    24m  24m_gini      3m   3m_gini
#  0             0    Klf13  0.029782  Satb1  0.069520   Satb1  0.078535
#  1             1     Jund  0.026821   Ets1  0.040100    Jund  0.046138
#  2             2      Fos  0.022536   Tcf7  0.035630    Ets1  0.041301
#  3             3  Hnrnpab  0.015421   Bcl6  0.023543  Hnrnpk  0.034209
#  4             4   Hnrnpk  0.010609  Taf10  0.018349     Fos  0.029983
#  ..          ...      ...       ...    ...       ...     ...       ...
#  632         632     Isl1  0.000159    NaN       NaN     NaN       NaN
#  633         633    Hoxa5  0.000159    NaN       NaN     NaN       NaN
#  634         634     Rarb  0.000156    NaN       NaN     NaN       NaN
#  635         635   Zfp599  0.000151    NaN       NaN     NaN       NaN
#  636         636   Cdkn2a  0.000137    NaN       NaN     NaN       NaN
#
#  [637 rows x 7 columns],
#  'Liver':      Unnamed: 0    18m  18m_gini      24m  24m_gini     3m   3m_gini
#  0             0   Ybx1  0.025259      Fos  0.014443   Egr1  0.036739
#  1             1   Egr1  0.023739     Ybx1  0.013123    Fos  0.033014
#  2             2  Klf13  0.020975     Nfia  0.011815  Klf13  0.020340
#  3             3   Jund  0.016004    Cebpa  0.010436    Jun  0.019981
#  4             4   Btg2  0.015305    Pcbp1  0.010195   Jund  0.019352
#  ..          ...    ...       ...      ...       ...    ...       ...
#  420         420    NaN       NaN     Zfp1  0.000768    NaN       NaN
#  421         421    NaN       NaN    Zmym3  0.000757    NaN       NaN
#  422         422    NaN       NaN    Deaf1  0.000745    NaN       NaN
#  423         423    NaN       NaN     Rarb  0.000714    NaN       NaN
#  424         424    NaN       NaN  Cbfa2t2  0.000700    NaN       NaN
#
#  [425 rows x 7 columns],
#  'Kidney':       Unnamed: 0    18m  18m_gini      24m  24m_gini      3m   3m_gini
#  0              0   Jund  0.013931     Ybx1  0.019635     Fos  0.034973
#  1              1    Fos  0.013369    Hmgb2  0.010487    Jund  0.032068
#  2              2   Btg2  0.010316     Eno1  0.009744    Ybx1  0.027306
#  3              3  Foxq1  0.010114    Klf13  0.008225    Hdgf  0.016167
#  4              4   Ybx1  0.008582  Hnrnpab  0.008071  Ctnnb1  0.015730
#  ...          ...    ...       ...      ...       ...     ...       ...
#  1056        1056    NaN       NaN     Rfx8  0.000000     NaN       NaN
#  1057        1057    NaN       NaN    Foxr2  0.000000     NaN       NaN
#  1058        1058    NaN       NaN     Gbx2  0.000000     NaN       NaN
#  1059        1059    NaN       NaN      Rax  0.000000     NaN       NaN
#  1060        1060    NaN       NaN    Klf17  0.000000     NaN       NaN
#
#  [1061 rows x 7 columns],
#  'Heart':      Unnamed: 0      18m  18m_gini      24m  24m_gini       3m   3m_gini
#  0             0     Jund  0.038535     Nfia  0.015101     Jund  0.061408
#  1             1    Klf13  0.013415     Jund  0.014050     Nfia  0.026341
#  2             2      Fos  0.012792   Zbtb20  0.013962  Tsc22d3  0.021841
#  3             3     Ybx1  0.012539  Tsc22d3  0.012162     Klf9  0.017979
#  4             4  Tsc22d3  0.012404    Ssbp4  0.009517   Zbtb20  0.016548
#  ..          ...      ...       ...      ...       ...      ...       ...
#  844         844      NaN       NaN    Foxo6  0.000035      NaN       NaN
#  845         845      NaN       NaN    Foxg1  0.000034      NaN       NaN
#  846         846      NaN       NaN     Pax3  0.000034      NaN       NaN
#  847         847      NaN       NaN     Rfx8  0.000033      NaN       NaN
#  848         848      NaN       NaN   Tfap2e  0.000032      NaN       NaN
#
#  [849 rows x 7 columns],
#  'Brain_Myeloid':      Unnamed: 0     18m  18m_gini    24m  24m_gini       3m   3m_gini
#  0             0     Fos  0.028505    Jun  0.025679      Fos  0.095189
#  1             1    Egr1  0.016373  Cebpa  0.018991      Jun  0.049582
#  2             2     Jun  0.016181  Cebpb  0.018851     Egr1  0.040248
#  3             3    Irf8  0.014148  Ncoa3  0.018547     Btg2  0.025128
#  4             4   Cebpa  0.014094    Fos  0.018511  Tsc22d3  0.023563
#  ..          ...     ...       ...    ...       ...      ...       ...
#  844         844   Nr1i3  0.000015    NaN       NaN      NaN       NaN
#  845         845   Tshz3  0.000014    NaN       NaN      NaN       NaN
#  846         846    Pax8  0.000014    NaN       NaN      NaN       NaN
#  847         847  Zfp831  0.000014    NaN       NaN      NaN       NaN
#  848         848    Tbx2  0.000013    NaN       NaN      NaN       NaN
#
#  [849 rows x 7 columns],
#  'Brain_Non-Myeloid':       Unnamed: 0      18m  18m_gini      24m  24m_gini       3m   3m_gini
#  0              0     Jund  0.032254   Hnrnpk  0.019906     Jund  0.041250
#  1              1  Tsc22d1  0.019366     Nfia  0.013134     Sox8  0.020919
#  2              2    Klf13  0.019121  Tsc22d3  0.013022    Klf13  0.020503
#  3              3     Sox8  0.016365     Atf3  0.012582  Tsc22d4  0.018045
#  4              4     Skil  0.013139     Cnbp  0.012358   Srebf1  0.014437
#  ...          ...      ...       ...      ...       ...      ...       ...
#  1056        1056      NaN       NaN    Foxr2  0.000000      NaN       NaN
#  1057        1057      NaN       NaN    Hoxd4  0.000000      NaN       NaN
#  1058        1058      NaN       NaN      Sry  0.000000      NaN       NaN
#  1059        1059      NaN       NaN    Foxn4  0.000000      NaN       NaN
#  1060        1060      NaN       NaN   Tfap2d  0.000000      NaN       NaN
#
#  [1061 rows x 7 columns],
#  'Aorta':      Unnamed: 0    18m  18m_gini    24m  24m_gini      3m   3m_gini
#  0             0   Jund  0.022146   Ybx1  0.039200    Jund  0.035546
#  1             1  Aebp1  0.016905   Pbx1  0.027583     Fos  0.023970
#  2             2    Fos  0.015722   Bcl6  0.018548    Ybx1  0.020675
#  3             3   Junb  0.012196  Klf13  0.018205    Ier2  0.018419
#  4             4   Nfia  0.011949   Klf2  0.016319    Junb  0.016758
#  ..          ...    ...       ...    ...       ...     ...       ...
#  844         844    NaN       NaN    NaN       NaN   Myod1  0.000054
#  845         845    NaN       NaN    NaN       NaN  Sohlh2  0.000053
#  846         846    NaN       NaN    NaN       NaN  Gm3604  0.000053
#  847         847    NaN       NaN    NaN       NaN   Rbpjl  0.000043
#  848         848    NaN       NaN    NaN       NaN    Pax7  0.000035
#
#  [849 rows x 7 columns],
#  'BAT':      Unnamed: 0   18m  18m_gini      24m  24m_gini     3m   3m_gini
#  0             0  Fli1  0.025311     Fli1  0.025616   Jund  0.056971
#  1             1  Junb  0.024386     Ets1  0.020483   Junb  0.015730
#  2             2  Jund  0.015700     Irf2  0.016083   Klf2  0.014353
#  3             3  Eno1  0.014140  Gpbp1l1  0.014791  Satb1  0.013871
#  4             4   Fos  0.013958     Sub1  0.014208   Ier2  0.013658
#  ..          ...   ...       ...      ...       ...    ...       ...
#  420         420   NaN       NaN    Tfcp2  0.000553    NaN       NaN
#  421         421   NaN       NaN   Zfp317  0.000547    NaN       NaN
#  422         422   NaN       NaN    Foxd4  0.000537    NaN       NaN
#  423         423   NaN       NaN   Zfp560  0.000510    NaN       NaN
#  424         424   NaN       NaN    Grhl3  0.000464    NaN       NaN
#
#  [425 rows x 7 columns]}

# %%
def scatterplotResults (scRFEres, tissueList, label, seq, nEst):
    plotRes = {}
    for t in tissueList: 
        plt.figure()
        print(t)
        plotRes[t] = sns.scatterplot(x=scRFEres[t][label+'_gini'][0:20], y=scRFEres[t][label][0:20])
        plotRes[t].invert_yaxis()
        plotRes[t].set(xlabel=t+'_'+label+'_gini', ylabel = t+'-'+label+'_gene')
        plotRes[t].set_title(t+'_'+label+'_'+seq+'_'+nEst)
        plt.savefig(t+'_'+label+'_'+seq+'_'+nEst+'.png')

# %%
cd /Users/madelinepark/desktop/scRFEfigs/facsTissAgetfPlot
# Out:
# /Users/madelinepark/Desktop/scRFEfigs/facsTissAgetfPlot

# %%
scatterplotResults(scRFEres = facsTissAgetfsResults, tissueList = facsTissueList,
                   label='3m', seq='facs', nEst='5000')
#before running, check what labels your csv has (ex: some tissues don't have certain ages)
# Out:
# SCAT
# Large_Intestine
# Diaphragm
# Marrow
# Mammary_Gland
# Pancreas
# Lung
# Bladder
# MAT
# Tongue
# Spleen
# Skin
# Limb_Muscle
# Trachea
# GAT
# Thymus
# Liver
# Kidney
# Heart
# Brain_Myeloid
# /Users/madelinepark/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
# Brain_Non-Myeloid
# Aorta
# BAT

# %% [markdown]
# ## Make plots for dropletTissAge5000

# %%
# https://seaborn.pydata.org/generated/seaborn.scatterplot.html
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
# tips = sns.load_dataset("tips")
# ax = sns.scatterplot(x="total_bill", y="tip", data=tips)

# %%
ax = sns.scatterplot(x=Marrow['18m_gini'][0:20], y=Marrow['18m'][0:20] )
ax.invert_yaxis()
ax.set(xlabel="Marrow_18m_gini", ylabel = "Marrow_18m_gene")
ax.set_title('Marrow_18m_Droplet_5000')
# Out:
# Text(0.5, 1.0, 'Marrow_18m_Droplet_5000')

# %%
cd /users/madelinepark/Desktop
# Out:
# /Users/madelinepark/Desktop

# %%
# dict with name of tissue and corresponding results csv
dropletTissAgetfsResults = {
'Marrow': pd.read_csv('/Users/madelinepark/Downloads/dropletTissAgetfsResults/Marrow_droplet_tf_age_5000.csv'),
'Lung': pd.read_csv('/Users/madelinepark/Downloads/dropletTissAgetfsResults/Lung_droplet_tf_age_5000.csv'),
'Bladder': pd.read_csv('/Users/madelinepark/Downloads/dropletTissAgetfsResults/Bladder_droplet_tf_age_5000.csv'),
'Tongue': pd.read_csv('/Users/madelinepark/Downloads/dropletTissAgetfsResults/Tongue_droplet_tf_age_5000.csv'),
'Trachea': pd.read_csv('/Users/madelinepark/Downloads/dropletTissAgetfsResults/Trachea_droplet_tf_age_5000.csv'),
# 'Large_Intestine': pd.read_csv('/Users/madelinepark/Downloads/dropletTissAgetfsResults/Large_Intestine_droplet_tf_age_5000.csv'),
'Mammary_Gland': pd.read_csv('/Users/madelinepark/Downloads/dropletTissAgetfsResults/Mammary_Gland_droplet_tf_age_5000.csv'),
# 'Fat': pd.read_csv('/Users/madelinepark/Downloads/dropletTissAgetfsResults/Fat_droplet_tf_age_5000.csv'),
# 'Pancreas': pd.read_csv('/Users/madelinepark/Downloads/dropletTissAgetfsResults/Pancreas_droplet_tf_age_5000.csv'),
# 'Skin': pd.read_csv('/Users/madelinepark/Downloads/dropletTissAgetfsResults/Skin_droplet_tf_age_5000.csv'),
'Liver': pd.read_csv('/Users/madelinepark/Downloads/dropletTissAgetfsResults/Liver_droplet_tf_age_5000.csv'),
'Kidney': pd.read_csv('/Users/madelinepark/Downloads/dropletTissAgetfsResults/Kidney_droplet_tf_age_5000.csv'),
'Heart_and_Aorta': pd.read_csv('/Users/madelinepark/Downloads/dropletTissAgetfsResults/Heart_and_Aorta_droplet_tf_age_5000.csv'),
'Limb_Muscle': pd.read_csv('/Users/madelinepark/Downloads/dropletTissAgetfsResults/Limb_Muscle_droplet_tf_age_5000.csv'),
'Spleen': pd.read_csv('/Users/madelinepark/Downloads/dropletTissAgetfsResults/Spleen_droplet_tf_age_5000.csv'),
'Thymus': pd.read_csv('/Users/madelinepark/Downloads/dropletTissAgetfsResults/Thymus_droplet_tf_age_5000.csv')
}

# %%
cd /Users/madelinepark/Desktop/scRFEfigs/dropletTissAgetfPlot/
# Out:
# /Users/madelinepark/Desktop/scRFEfigs/dropletTissAgetfPlot

# %%
def scatterplotResults (scRFEres, tissueList, label, seq, nEst):
    plotRes = {}
    for t in tissueList: 
        plt.figure()
        print(t)
        plotRes[t] = sns.scatterplot(x=scRFEres[t][label+'_gini'][0:20], y=scRFEres[t][label][0:20])
        plotRes[t].invert_yaxis()
        plotRes[t].set(xlabel=t+'_'+label+'_gini', ylabel = t+'-'+label+'_gene')
        plotRes[t].set_title(t+'_'+label+'_'+seq+'_'+nEst)
        plt.savefig(t+'_'+label+'_'+seq+'_'+nEst+'.png')

# %%
# dropletTissueList = ['Marrow','Lung','Bladder','Tongue','Trachea','Large_Intestine','Mammary_Gland',
#                  'Fat','Pancreas','Skin','Liver','Kidney','Heart_and_Aorta','Limb_Muscle',
#                  'Spleen','Thymus']

dropletTissueList = ['Marrow','Lung','Bladder','Tongue','Trachea','Mammary_Gland',
                 'Liver','Kidney','Heart_and_Aorta','Limb_Muscle',
                 'Spleen','Thymus']

# %%
scatterplotResults(scRFEres = dropletTissAgetfsResults, tissueList = dropletTissueList,
                   label='3m', seq='droplet', nEst='5000')
#before running, check what labels your csv has (ex: some tissues don't have certain ages)
# Out:
# Marrow
# Lung
# Bladder
# Tongue
# Trachea
# Mammary_Gland
# Liver
# Kidney
# Heart_and_Aorta
# Limb_Muscle
# Spleen
# Thymus
