# %% [markdown]
# # Sorting Results

# %%
# Imports 
import numpy as np
import pandas as pd
import scanpy as sc
from anndata import read_h5ad
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import accuracy_score
from sklearn.feature_selection import RFE
from sklearn.feature_selection import RFECV

# %%
cd scrfe test results
# Out:
# /Users/madelinepark/Desktop/SCRFE TEST RESULTS

# %%
kidney_facs_1000_age = pd.read_csv('KidneyFacsAge1000TissReset.csv')

# %%
# kidney_facs_1000_age

# %%
def sortVals(df):
    cols = df.columns.to_list()
    print(cols[1])
    return df.sort_values(by = cols[2], ascending=False)

# %%
sortVals(kidney_facs_1000_age)

# %%
kidney_facs_1000_cell = pd.read_csv('KidneyFacsCell1000TissReset.csv')

# %%
sortVals(kidney_facs_1000_cell).head()
# Out:
# Kidney-new-24m-cluster
#    Unnamed: 0 Kidney-new-24m-cluster  Kidney-new-24m-cluster_gini  \
# 0           0                 Beta-s                     0.457965
# 3           3                Sec14l3                     0.266172
# 1           1                Gm16861                     0.173545
# 2           2                  Plin5                     0.102318
# 4           4                    NaN                          NaN
#
#   kidney loop of Henle ascending limb epithelial cell  \
# 0                                            Slc12a1
# 3                                                NaN
# 1                                                NaN
# 2                                                NaN
# 4                                                NaN
#
#    kidney loop of Henle ascending limb epithelial cell_gini fenestrated cell  \
# 0                                                1.0           0610007C21Rik
# 3                                                NaN           0610007P14Rik
# 1                                                NaN           0610007L01Rik
# 2                                                NaN           0610007N19Rik
# 4                                                NaN           0610009D07Rik
#
#    fenestrated cell_gini mesangial cell  mesangial cell_gini B cell  ...  \
# 0               0.000000  0610007C21Rik         2.071603e-05   Ccr7  ...
# 3               0.000000  0610007P08Rik         0.000000e+00  Ms4a1  ...
# 1               0.000000  0610007L01Rik         8.220964e-07  Cd79a  ...
# 2               0.000059  0610007N19Rik         0.000000e+00   Ly6d  ...
# 4               0.000000  0610007P14Rik         0.000000e+00    NaN  ...
#
#    kidney collecting duct epithelial cell  \
# 0                           0610005C13Rik
# 3                           0610007P14Rik
# 1                           0610007C21Rik
# 2                           0610007N19Rik
# 4                           0610009D07Rik
#
#   kidney collecting duct epithelial cell_gini         T cell T cell_gini  \
# 0                                    0.000239  0610007C21Rik    0.000042
# 3                                    0.000009  0610007P14Rik    0.000054
# 1                                    0.000141  0610007L01Rik    0.000100
# 2                                    0.000100  0610007N19Rik    0.000000
# 4                                    0.000067  0610007P22Rik    0.000050
#
#    kidney collecting duct principal cell  \
# 0                                    Clu
# 3                                Slc12a3
# 1                          D630042F21Rik
# 2                                  Pgam2
# 4                                    NaN
#
#   kidney collecting duct principal cell_gini     macrophage macrophage_gini  \
# 0                                   0.120505  0610007N19Rik        0.000000
# 3                                   0.287090  0610007P22Rik        0.000000
# 1                                   0.153364  0610007P08Rik        0.000000
# 2                                   0.439040  0610007P14Rik        0.000015
# 4                                        NaN  0610008F07Rik        0.000000
#
#    epithelial cell of proximal tubule epithelial cell of proximal tubule_gini
# 0                       0610005C13Rik                                0.000076
# 3                       0610007N19Rik                                0.000084
# 1                       0610007C21Rik                                0.000065
# 2                       0610007L01Rik                                0.000068
# 4                       0610007P14Rik                                0.000011
#
# [5 rows x 21 columns]

# %%
heart_droplet_1000_age = pd.read_csv('HeartDropletAge1000TissReset.csv')

# %%
sortVals(heart_droplet_1000_age).head()
# Out:
# 24m
#       Unnamed: 0         24m  24m_gini      30m  30m_gini            18m  \
# 3309        3309      Beta-s  0.011999   Picalm  0.000226       Serpinh1
# 3932        3932        Xist  0.010437    Cox7b  0.000291           Pgk1
# 2539        2539  Rps15a-ps4  0.007371     Heyl  0.000123         Pabpc4
# 430          430  Rps15a-ps6  0.007011    Stat2  0.000072           Myl6
# 517          517      Gm1821  0.006476  Adamts2  0.000071  9530068E07Rik
#
#       18m_gini     21m  21m_gini   1m  1m_gini             3m   3m_gini
# 3309  0.000396  Lrrc32  0.000139  NaN      NaN  1110004F10Rik  0.000215
# 3932  0.000258  Gm6377  0.000227  NaN      NaN           Bex4  0.000058
# 2539  0.000109  Pabpc4  0.000126  NaN      NaN        Gm12657  0.000618
# 430   0.000399    Ppia  0.000383  NaN      NaN           Eea1  0.000400
# 517   0.000138     Ubb  0.000853  NaN      NaN          Ehbp1  0.000137
